# %% [markdown]
# Download FER-2013 from Kaggle

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: packaging in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: webencodings in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests->kaggle) (3.7)

# %%
# !pip install mediapipe
# !pip install tensorflow
# Out:
# Requirement already satisfied: mediapipe in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (0.10.18)
# Requirement already satisfied: absl-py in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: jaxlib in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (0.4.35)
# Requirement already satisfied: matplotlib in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: numpy<2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (4.25.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: sentencepiece in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.4.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: tensorflow in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install pandas
# !pip install scikit-learn
# !pip install scikit-image
# Out:
# Requirement already satisfied: opencv-python in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scikit-image in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (10.4.0)
# Requirement already satisfied: imageio>=2.33 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: packaging>=21 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from scikit-image) (0.4)

# %%
import os
# Specify the directory to save the dataset
save_directory_data = os.path.expanduser('~/Downloads')
os.makedirs(save_directory_data, exist_ok=True)
# Download the dataset
os.system(f'kaggle datasets download -d msambare/fer2013 -p "{save_directory_data}"')
# !pip install xgboost
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# fer2013.zip: Skipping, found more recently modified local copy (use --force to force download)
# Requirement already satisfied: xgboost in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: numpy in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /Users/sherrywang/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)

# %%
import cv2
import matplotlib.pyplot as plt
import random
from collections import Counter
import numpy as np
import pandas as pd
import random
from torchvision import transforms
from PIL import Image
from sklearn.model_selection import train_test_split
import shutil
from sklearn.preprocessing import LabelEncoder
from skimage import exposure
import os
import matplotlib.pyplot as plt
import mediapipe as mp
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVC
import cv2
from skimage.filters import gabor_kernel
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.feature import hog
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from time import time, sleep
xPixel = 48  
yPixel = 48

# %%
# Directory paths
train_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/train')
test_dir = os.path.expanduser('/Users/sherrywang/Desktop/fer2013/test')

# %%
# Define a function to load data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)

print(f"Loaded {len(train_images)} training images and {len(test_images)} testing images.")
# Out:
# Loaded 28709 training images and 7178 testing images.

# %%
# Define a function to count the number of images in each category
def count_images_per_category(labels, dataset_label):
    category_counts = Counter(labels)
    total_images = len(labels)
    
    # Print the counts for each category
    print(f"\n{dataset_label} set:")
    for category, count in category_counts.items():
        print(f"Category '{category}': {count} images")
    
    print(f"Total number of images in {dataset_label} set: {total_images}")
    return category_counts, total_images

# Count images in training and testing
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
test_counts, num_test_images = count_images_per_category(test_labels, "Testing")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709
#
# Testing set:
# Category 'happy': 1774 images
# Category 'sad': 1247 images
# Category 'fear': 1024 images
# Category 'surprise': 831 images
# Category 'neutral': 1233 images
# Category 'angry': 958 images
# Category 'disgust': 111 images
# Total number of images in Testing set: 7178

# %% [markdown]
# Visualzie Random Samples from Each Category

# %%
# Define a function to visualize random samples from each category
def visualize_samples(images, labels, num_samples=5, dataset_label="Dataset"):
    unique_labels = set(labels)
    
    for label in unique_labels:
        label_images = [img for img, lbl in zip(images, labels) if lbl == label]
        
        print(f"Label: {label}")
        sample_images = random.sample(label_images, min(num_samples, len(label_images)))
        
        plt.figure(figsize=(15, 3))
        for i, image in enumerate(sample_images):
            plt.subplot(1, num_samples, i + 1)
            plt.imshow(image, cmap='gray')
            plt.title(label)
            plt.axis('off')
        
        plt.show()

# Visualize samples from training and testing
visualize_samples(train_images, train_labels, num_samples=5, dataset_label="Training")
visualize_samples(test_images, test_labels, num_samples=5, dataset_label="Testing")
# Out:
# Label: happy
# Label: neutral
# Label: surprise
# Label: angry
# Label: disgust
# Label: fear
# Label: sad
# Label: happy
# Label: neutral
# Label: surprise
# Label: angry
# Label: disgust
# Label: fear
# Label: sad

# %% [markdown]
# Data Cleaning

# %%
# Define a function to check if images are loaded correctly and correct size
def check_images(images, labels, dataset_label="Dataset"):
    invalid_images = []
    for i, image in enumerate(images):
        if image is None or image.shape != (48, 48):
            print(f"Invalid image detected in {dataset_label} set: Label - {labels[i]}, Index - {i}")
            invalid_images.append((labels[i], i))  # Store label and index of invalid images
    print(f"Total invalid images in {dataset_label} set: {len(invalid_images)}")

# Check the training and testing sets in memory
check_images(train_images, train_labels, dataset_label="Training")
check_images(test_images, test_labels, dataset_label="Testing")
# Out:
# Total invalid images in Training set: 0
# Total invalid images in Testing set: 0

# %% [markdown]
# Addressing Data Imbalance: Step 1 Downsample 'happy' to 5000 Images

# %% [markdown]
# Addressing Data Imbalance: Step 2 Augmentation

# %% [markdown]
# Count the Number of Images in Each Category

# %%
# Load training balanced dataset
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)
# Count images in training balanced dataset
train_counts, num_train_images = count_images_per_category(train_labels, "Training")
# Out:
# Training set:
# Category 'happy': 7215 images
# Category 'sad': 4830 images
# Category 'fear': 4097 images
# Category 'surprise': 3171 images
# Category 'neutral': 4965 images
# Category 'angry': 3995 images
# Category 'disgust': 436 images
# Total number of images in Training set: 28709

# %% [markdown]
# Feature Extraction for Training Balanced Dataset

# %%
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True, max_num_faces=1, refine_landmarks=True)  


def extract_mediapipe_features(image, label_images):
 
    """
    Extract facial landmarks using MediaPipe Face Mesh. If no face is detected,
    continually retry with a randomly selected and augmented image from the same label.
    
    Parameters:
    - image: The initial input image to extract features from.
    - label_images: List of images under the same label to select from if retry is needed.
    
    Returns:
    - feature_vector: List of landmark (x, y, z) coordinates.
    """

    while True:
        # Ensure image is of type uint8 (0-255 range)
        image_uint8 = np.array(image, dtype=np.uint8)
        
        # Convert to RGB if grayscale
        if len(image_uint8.shape) == 2:  # Grayscale image
            image_rgb = cv2.cvtColor(image_uint8, cv2.COLOR_GRAY2RGB)
        else:
            image_rgb = image_uint8
        
        # Verify and re-cast to ensure MediaPipe compatibility
        image_rgb = np.array(image_rgb, dtype=np.uint8)
        #print("Image shape after conversion:", image_rgb.shape, "Data type:", image_rgb.dtype)
        
        # Process with MediaPipe Face Mesh
        results = face_mesh.process(image_rgb)
        
        if results.multi_face_landmarks:
            # Extract landmark coordinates for the detected face
            feature_vector = []
            for landmark in results.multi_face_landmarks[0].landmark:
                x, y, z = landmark.x, landmark.y, landmark.z
                #flattened 1d features
                feature_vector.extend([x, y, z]) 
                #feature_vector.append([x, y, z])
            return feature_vector  # Return feature vector if landmarks are detected
        
        # If no face is detected, print message and retry with augmented image
        print("No face detected in the image. Retrying with augmented image...")
        image = random.choice(label_images)  # Randomly choose a new image from the same label


# Process each category separately
train_features = []
test_features = []
for label in set(train_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(train_images, train_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            train_features.append(feature_vector)

print("Feature extraction completed.")

for label in set(test_labels):  # Iterate over each unique label
    # Filter images and labels for the current label
    label_images = [img for img, lbl in zip(test_images, test_labels) if lbl == label]
    
    # Process each image in the current label category
    for i, image in enumerate(label_images):
        #print(f"Processing image {i+1}/{len(label_images)} for label '{label}'")
        feature_vector = extract_mediapipe_features(image, label_images)  # Pass both image and label_images
        if feature_vector is not None:
            test_features.append(feature_vector)

print("Feature extraction completed.")


# Encode labels
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)

# Specify the directory to save extracted features and encoded labels
save_directory_features = os.path.expanduser('~/Downloads/fer2013/ExtractedFeatures_media')
os.makedirs(save_directory_features, exist_ok=True)

# Save MediaPipe features and encoded labels
np.save(f'{save_directory_features}/train_Media.npy', train_features)
np.save(f'{save_directory_features}/train_labels_encoded_Media.npy', train_labels_encoded)
print("Features and labels saved successfully.")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732930674.833691 9384879 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M3
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1732930674.845067 9386532 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1732930674.849367 9386533 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1732930674.851885 9386536 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# ...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# No face detected in the image. Retrying with augmented image...
# Feature extraction completed.
# Features and labels saved successfully.

# %%
# Load training balanced dataset
test_images, test_labels = load_images_from_directory(test_dir)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_features)

# Apply PCA to reduce dimensionality
pca = PCA(n_components=15)
X_train_pca = pca.fit_transform(X_train_scaled)

# Check the amount of variance explained by the components
explained_variance = np.sum(pca.explained_variance_ratio_)
print(f"Explained variance with {pca.n_components_} components: {explained_variance:.2f}")
# Out:
# Explained variance with 15 components: 1.00

# %%
import numpy as np
import pandas as pd
import os
import cv2
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
test_scaled_features = scaler.transform(test_features)

# Apply PCA
transformed_features_test = pca.transform(test_scaled_features)

# %%
# set up X, y of train and test
train_Class = np.array(train_labels)
train_images = np.array(train_images)

test_Class = np.array(test_labels)
test_images = np.array(test_images)

# %%
transformed_features_test.shape
# Out:
# (7178, 15)

# %%
X_train_pca.shape
# Out:
# (28709, 15)

# %%
train_images_Media = X_train_pca

# %%
test_images_Media = transformed_features_test

# %%
#Gabor PCA + mediapipe PCA + RF
# define the separate function to apply gabor filter and HOG features extraction at the same time
def Gabor(image):
    kernel = np.real(gabor_kernel(
                    frequency=2, 
                    theta=2/4*np.pi,
                    sigma_x=1, sigma_y=1))

    filtered_image = cv2.filter2D(image, cv2.CV_8UC3, kernel)
    return filtered_image

# Apply the Gabor and HOG respectively to each image
train_images_Gabor = []
for i in range(train_images.shape[0]):
    image = train_images[i]
    filtered_image = Gabor(image)
    train_images_Gabor.append(filtered_image)
train_images_Gabor = np.array(train_images_Gabor)
train_images_Gabor = train_images_Gabor.reshape((train_images_Gabor.shape[0],-1))
print(train_images_Gabor.shape)  # Print the shape of the resulting feature array


test_images_Gabor = []
for i in range(test_images.shape[0]):
    image = test_images[i]
    filtered_image = Gabor(image)
    test_images_Gabor.append(filtered_image)
test_images_Gabor = np.array(test_images_Gabor)
test_images_Gabor = test_images_Gabor.reshape((test_images_Gabor.shape[0],-1))
print(test_images_Gabor.shape)  # Print the shape of the resulting feature array
# Out:
# (28709, 2304)
# (7178, 2304)

# %%
# Apply PCA to Gabor data
from sklearn.decomposition import PCA
# Standardize the data and PCA
scaler = StandardScaler()
scaler.fit(train_images_Gabor)
train_images_Gabor_scaled = scaler.transform(train_images_Gabor)
test_images_Gabor_scaled = scaler.transform(test_images_Gabor)

pca = PCA()  # Keep all components initially
principalComponents = pca.fit_transform(train_images_Gabor_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

# Find the index where cumulative variance exceeds 0.995
n_components = len(cumulative_variance_ratio[cumulative_variance_ratio <= 0.995]) + 1 

print(f"Number of components to explain 99.5% variance: {n_components}")

# do the PCA transformation to the Gabor data
pca = PCA(n_components=n_components)
train_images_Gabor_pca = pca.fit_transform(train_images_Gabor_scaled)
test_images_Gabor_pca = pca.transform(test_images_Gabor_scaled)
print(train_images_Gabor_pca.shape)
print(test_images_Gabor_pca.shape)
# Out:
# Number of components to explain 99.5% variance: 254
# (28709, 254)
# (7178, 254)

# %%
# Combine Gabar and HOG data
train_images_pca = np.concatenate((train_images_Gabor_pca, train_images_Media), axis=1)
test_images_pca = np.concatenate((test_images_Gabor_pca, test_images_Media), axis=1)
print(train_images_pca.shape)
print(test_images_pca.shape)
# Out:
# (28709, 269)
# (7178, 269)

# %%
#GPU XGB
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pandas as pd

def auto_xgboost(
    X,
    y,
    n_estimators=200,
    random_state=2024,
    cv=10
    ):
    # 1. Parameter grid
    param_grid = {
        'max_depth': [5, 10, 20, 30],
        'learning_rate': [0.01, 0.05, 0.1],
        'colsample_bytree': [0.1, 0.3, 0.5]
        # 'min_child_weight': [1, 2, 5, 10, 20]
        # 'gamma': [0, 0.1],
        # 'subsample': [0.8, 1.0]
    }
    
    # 2. Create base model with GPU support
    xgb_model = XGBClassifier(
        objective='multi:softmax',
        n_estimators=n_estimators,
        subsample=0.3,  # randomly sample 30% of the training data for each tree, avoid overfitting
        eval_metric='merror',
        random_state=random_state,
        tree_method='hist',  # Histogram method (GPU acceleration)
        device='cuda',  # Use GPU for training
        use_label_encoder=False,  # Avoid label encoding warnings
    )


    # 3. Setup StratifiedKFold
    skf = StratifiedKFold(
        n_splits=cv,
        shuffle=True,
        random_state=random_state
    )

    # 4. Setup GridSearchCV
    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        cv=skf,
        scoring='accuracy',
        n_jobs=10,  # Use all available CPU cores for parallelism during cross-validation
        verbose=2  # detailed output monitoring progress updates
    )

    # 5. Scale the features
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 6. Fit the model
    grid_search.fit(X_scaled, y_encoded)

    # 7. Best model
    best_model = grid_search.best_estimator_
    
    # 8. Best params
    best_par = grid_search.best_params_
    
    # 9. Best CV score
    best_score = grid_search.best_score_

    # 10. Feature importance
    feature_importance = pd.DataFrame({
        'feature': [f'feature_{i}' for i in range(X.shape[1])],
        'importance': best_model.feature_importances_
    })
    feature_importance = feature_importance.sort_values('importance', ascending=False)
    
    # compile and return the results
    results = {
        'best_params': best_par,
        'best_score': best_score,
        'best_model': best_model,
        'feature_importance': feature_importance
    }

    return results, grid_search

# %%
XGB_result, grid_search = auto_xgboost(X=train_images_pca, y=train_Class)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:33:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:23] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:35:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:38:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:39:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:46:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:47:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:55:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [21:57:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:21] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:22] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:08:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:15:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:16:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:17:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:21:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:27:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:33] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:34:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:35:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:36:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:39:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:39:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:39:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:39:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:40:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:47:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:54:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:55:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [22:56:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:00:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:00:32] WARNING: /workspace/src/learner.cc:740:
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:51:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:51:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:51:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:52:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:53:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [23:57:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:03:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:03:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:03:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:03:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:03:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:04:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:04:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:04:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:04:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:04:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:10:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:12:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:15:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:16:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:21:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [00:27:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# loop through and print the results
for key, value in XGB_result.items():
    print(f"{key}: \n {value}")
# Out:
# best_params:
#  {'colsample_bytree': 0.5, 'learning_rate': 0.1, 'max_depth': 30}
# best_score:
#  0.5273254835996637
# best_model:
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=30,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softmax', ...)
# feature_importance:
#           feature  importance
# 261  feature_261    0.013165
# 260  feature_260    0.012310
# 267  feature_267    0.008088
# 262  feature_262    0.006966
# 263  feature_263    0.006142
# ..           ...         ...
# 163  feature_163    0.003095
# 99    feature_99    0.003079
# 151  feature_151    0.003072
# 189  feature_189    0.003071
# 78    feature_78    0.003034
#
# [269 rows x 2 columns]
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.1min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 5.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.5min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=20; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.01, max_depth=30; total time= 8.5min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.8min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 6.0min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.05, max_depth=30; total time= 7.9min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=20; total time= 6.4min
# [CV] END colsample_bytree=0.1, learning_rate=0.1, max_depth=30; total time= 6.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20; total time= 7.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30; total time= 7.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=20; total time= 6.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=30; total time= 7.1min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5; total time= 1.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10; total time= 3.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20; total time= 5.8min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30; total time= 5.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=10; total time= 3.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20; total time= 7.2min
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30; total time= 7.5min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10; total time= 3.8min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=20; total time= 6.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=30; total time= 6.9min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5; total time= 1.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10; total time= 3.6min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20; total time= 5.7min
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30; total time= 5.7min

# %%
from xgboost import XGBClassifier

# %%
start_time = time()

# work on the test data set
# fit with the best model with 5000 trees

# encode the classes
label_encoder = LabelEncoder()
label_encoder.fit(train_Class)
train_Class_encoded = label_encoder.transform(train_Class)
test_Class_encoded = label_encoder.transform(test_Class)
# fit with the best model with 5000 trees

X_ttrain, X_val, y_ttrain, y_val = train_test_split(train_images_pca, train_Class_encoded, 
                                                  test_size=0.1, random_state=2024, stratify=train_Class_encoded)
    
    
xgb = XGBClassifier(base_score=None, booster=None, callbacks=None,
              colsample_bylevel=None, colsample_bynode=None,device='cuda',
              colsample_bytree=0.5, early_stopping_rounds=None,
              enable_categorical=False, eval_metric='merror',
              feature_types=None, gamma=None, grow_policy=None,
              importance_type=None, interaction_constraints=None,
              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
              max_cat_to_onehot=None, max_delta_step=None, max_depth=30,
              max_leaves=None, min_child_weight=None,n_estimators=200,
              n_jobs=None, num_parallel_tree=None, objective='multi:softmax')

xgb.fit(X_ttrain, y_ttrain, eval_set=[(X_val, y_val)])
train_Class_pred = xgb.predict(train_images_pca)
test_Class_pred = xgb.predict(test_images_pca)

end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# [0]	validation_0-merror:0.65064
# [1]	validation_0-merror:0.60223
# [2]	validation_0-merror:0.57018
# [3]	validation_0-merror:0.55416
# [4]	validation_0-merror:0.54336
# [5]	validation_0-merror:0.53117
# [6]	validation_0-merror:0.51933
# [7]	validation_0-merror:0.51620
# [8]	validation_0-merror:0.51445
# [9]	validation_0-merror:0.50540
# [10]	validation_0-merror:0.50087
# [11]	validation_0-merror:0.49565
# [12]	validation_0-merror:0.49565
# [13]	validation_0-merror:0.49181
# [14]	validation_0-merror:0.48763
# [15]	validation_0-merror:0.48346
# [16]	validation_0-merror:0.48102
# [17]	validation_0-merror:0.48137
# [18]	validation_0-merror:0.48137
# [19]	validation_0-merror:0.47753
# [20]	validation_0-merror:0.48067
# [21]	validation_0-merror:0.47719
# [22]	validation_0-merror:0.47370
# [23]	validation_0-merror:0.47684
# [24]	validation_0-merror:0.47475
# [25]	validation_0-merror:0.47057
# [26]	validation_0-merror:0.47022
# [27]	validation_0-merror:0.46917
# [28]	validation_0-merror:0.46743
# [29]	validation_0-merror:0.46778
# [30]	validation_0-merror:0.46395
# [31]	validation_0-merror:0.46499
# [32]	validation_0-merror:0.46430
# [33]	validation_0-merror:0.45873
# [34]	validation_0-merror:0.46082
# [35]	validation_0-merror:0.45803
# [36]	validation_0-merror:0.46012
# [37]	validation_0-merror:0.46012
# [38]	validation_0-merror:0.45489
# [39]	validation_0-merror:0.45524
# [40]	validation_0-merror:0.45315
# [41]	validation_0-merror:0.45420
# [42]	validation_0-merror:0.45489
# [43]	validation_0-merror:0.45315
# [44]	validation_0-merror:0.45455
# [45]	validation_0-merror:0.45455
# [46]	validation_0-merror:0.45385
# [47]	validation_0-merror:0.45280
# [48]	validation_0-merror:0.44862
# [49]	validation_0-merror:0.45002
# [50]	validation_0-merror:0.44828
# [51]	validation_0-merror:0.44862
# [52]	validation_0-merror:0.44619
# [53]	validation_0-merror:0.44723
# [54]	validation_0-merror:0.44653
# [55]	validation_0-merror:0.44793
# [56]	validation_0-merror:0.44444
# [57]	validation_0-merror:0.44793
# [58]	validation_0-merror:0.44653
# [59]	validation_0-merror:0.44758
# [60]	validation_0-merror:0.44653
# [61]	validation_0-merror:0.44619
# [62]	validation_0-merror:0.44479
# [63]	validation_0-merror:0.44514
# [64]	validation_0-merror:0.44688
# [65]	validation_0-merror:0.44723
# [66]	validation_0-merror:0.44375
# [67]	validation_0-merror:0.44375
# [68]	validation_0-merror:0.44653
# [69]	validation_0-merror:0.44584
# [70]	validation_0-merror:0.44410
# [71]	validation_0-merror:0.44479
# [72]	validation_0-merror:0.44619
# [73]	validation_0-merror:0.44549
# [74]	validation_0-merror:0.44514
# [75]	validation_0-merror:0.44270
# [76]	validation_0-merror:0.44340
# [77]	validation_0-merror:0.44201
# [78]	validation_0-merror:0.44340
# [79]	validation_0-merror:0.43957
# [80]	validation_0-merror:0.44061
# [81]	validation_0-merror:0.43992
# [82]	validation_0-merror:0.43817
# [83]	validation_0-merror:0.43713
# [84]	validation_0-merror:0.43504
# [85]	validation_0-merror:0.43678
# [86]	validation_0-merror:0.43713
# [87]	validation_0-merror:0.43539
# [88]	validation_0-merror:0.43539
# [89]	validation_0-merror:0.43643
# [90]	validation_0-merror:0.43608
# [91]	validation_0-merror:0.43400
# [92]	validation_0-merror:0.43469
# [93]	validation_0-merror:0.43400
# [94]	validation_0-merror:0.43469
# [95]	validation_0-merror:0.43434
# [96]	validation_0-merror:0.43400
# [97]	validation_0-merror:0.43469
# [98]	validation_0-merror:0.43469
# [99]	validation_0-merror:0.43400
# [100]	validation_0-merror:0.43434
# [101]	validation_0-merror:0.43330
# [102]	validation_0-merror:0.43295
# [103]	validation_0-merror:0.43400
# [104]	validation_0-merror:0.43434
# [105]	validation_0-merror:0.43225
# [106]	validation_0-merror:0.43051
# [107]	validation_0-merror:0.43156
# [108]	validation_0-merror:0.43156
# [109]	validation_0-merror:0.43121
# [110]	validation_0-merror:0.43191
# [111]	validation_0-merror:0.43156
# [112]	validation_0-merror:0.43051
# [113]	validation_0-merror:0.43016
# [114]	validation_0-merror:0.42738
# [115]	validation_0-merror:0.43121
# [116]	validation_0-merror:0.42877
# [117]	validation_0-merror:0.42982
# [118]	validation_0-merror:0.42842
# [119]	validation_0-merror:0.42842
# [120]	validation_0-merror:0.42912
# [121]	validation_0-merror:0.42807
# [122]	validation_0-merror:0.42842
# [123]	validation_0-merror:0.42912
# [124]	validation_0-merror:0.42842
# [125]	validation_0-merror:0.42912
# [126]	validation_0-merror:0.43016
# [127]	validation_0-merror:0.42738
# [128]	validation_0-merror:0.42877
# [129]	validation_0-merror:0.42912
# [130]	validation_0-merror:0.42738
# [131]	validation_0-merror:0.42773
# [132]	validation_0-merror:0.42947
# [133]	validation_0-merror:0.42807
# [134]	validation_0-merror:0.42738
# [135]	validation_0-merror:0.42912
# [136]	validation_0-merror:0.42738
# [137]	validation_0-merror:0.42773
# [138]	validation_0-merror:0.42912
# [139]	validation_0-merror:0.42668
# [140]	validation_0-merror:0.42633
# [141]	validation_0-merror:0.42703
# [142]	validation_0-merror:0.42738
# [143]	validation_0-merror:0.42598
# [144]	validation_0-merror:0.42598
# [145]	validation_0-merror:0.42633
# [146]	validation_0-merror:0.42633
# [147]	validation_0-merror:0.42668
# [148]	validation_0-merror:0.42564
# [149]	validation_0-merror:0.42773
# [150]	validation_0-merror:0.42807
# [151]	validation_0-merror:0.42633
# [152]	validation_0-merror:0.42529
# [153]	validation_0-merror:0.42564
# [154]	validation_0-merror:0.42668
# [155]	validation_0-merror:0.42668
# [156]	validation_0-merror:0.42738
# [157]	validation_0-merror:0.42842
# [158]	validation_0-merror:0.42703
# [159]	validation_0-merror:0.42668
# [160]	validation_0-merror:0.42598
# [161]	validation_0-merror:0.42564
# [162]	validation_0-merror:0.42529
# [163]	validation_0-merror:0.42494
# [164]	validation_0-merror:0.42459
# [165]	validation_0-merror:0.42320
# [166]	validation_0-merror:0.42355
# [167]	validation_0-merror:0.42215
# [168]	validation_0-merror:0.42215
# [169]	validation_0-merror:0.42250
# [170]	validation_0-merror:0.42320
# [171]	validation_0-merror:0.42146
# [172]	validation_0-merror:0.42250
# [173]	validation_0-merror:0.42076
# [174]	validation_0-merror:0.42250
# [175]	validation_0-merror:0.42215
# [176]	validation_0-merror:0.42146
# [177]	validation_0-merror:0.42250
# [178]	validation_0-merror:0.42041
# [179]	validation_0-merror:0.41971
# [180]	validation_0-merror:0.41902
# [181]	validation_0-merror:0.41902
# [182]	validation_0-merror:0.41937
# [183]	validation_0-merror:0.41867
# [184]	validation_0-merror:0.41797
# [185]	validation_0-merror:0.41902
# [186]	validation_0-merror:0.41971
# [187]	validation_0-merror:0.41937
# [188]	validation_0-merror:0.41902
# [189]	validation_0-merror:0.41762
# [190]	validation_0-merror:0.41693
# [191]	validation_0-merror:0.41902
# [192]	validation_0-merror:0.41902
# [193]	validation_0-merror:0.41971
# [194]	validation_0-merror:0.41902
# [195]	validation_0-merror:0.42006
# [196]	validation_0-merror:0.42076
# [197]	validation_0-merror:0.42041
# [198]	validation_0-merror:0.41902
# [199]	validation_0-merror:0.41867
# Runtime: 1.7880969007809957 mins

# %%
# test accuracy
print(accuracy_score(test_Class_encoded, test_Class_pred))
        
# classification_report
print(classification_report(test_Class_encoded, test_Class_pred))
# Out:
# 0.5979381443298969
#               precision    recall  f1-score   support
#
#            0       0.48      0.37      0.42       958
#            1       1.00      0.23      0.38       111
#            2       0.63      0.58      0.61      1024
#            3       0.75      0.88      0.81      1774
#            4       0.46      0.43      0.45      1233
#            5       0.47      0.60      0.53      1247
#            6       0.73      0.58      0.64       831
#
#     accuracy                           0.60      7178
#    macro avg       0.65      0.52      0.55      7178
# weighted avg       0.60      0.60      0.59      7178

# %%
# test accuracy
print(accuracy_score(train_Class_encoded, train_Class_pred))
        
# classification_report
print(classification_report(train_Class_encoded, train_Class_pred))
# Out:
# 0.9581315963635098
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3995
#            1       1.00      0.92      0.96       436
#            2       0.97      0.96      0.96      4097
#            3       0.97      0.99      0.98      7215
#            4       0.95      0.94      0.95      4965
#            5       0.93      0.96      0.95      4830
#            6       0.98      0.95      0.96      3171
#
#     accuracy                           0.96     28709
#    macro avg       0.96      0.95      0.96     28709
# weighted avg       0.96      0.96      0.96     28709
