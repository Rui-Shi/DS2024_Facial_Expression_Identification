# %%
import cv2
from skimage.filters import gabor_kernel
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage.feature import hog
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from time import time, sleep
xPixel = 48  
yPixel = 48

# %%
# Directory paths
train_dir = os.path.expanduser('../raw_data/fer2013/train')
test_dir = os.path.expanduser('../raw_data/fer2013/test')

# Define a function to load the balanced data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)


print(f"Loaded {len(train_images)} training images.")
print(f"Loaded {len(test_images)} testing images.")
# Out:
# Loaded 28709 training images.
# Loaded 7178 testing images.

# %%
# Check the train and test data
print({x: train_labels.count(x) for x in set(train_labels)})
print(np.array(train_images).shape)

print({x: test_labels.count(x) for x in set(test_labels)})
print(np.array(test_images).shape)
# Out:
# {'neutral': 4965, 'surprise': 3171, 'fear': 4097, 'sad': 4830, 'disgust': 436, 'angry': 3995, 'happy': 7215}
# (28709, 48, 48)
# {'neutral': 1233, 'surprise': 831, 'fear': 1024, 'sad': 1247, 'disgust': 111, 'angry': 958, 'happy': 1774}
# (7178, 48, 48)

# %%
# set up X, y of train and test
train_Class = np.array(train_labels)
train_images = np.array(train_images)

test_Class = np.array(test_labels)
test_images = np.array(test_images)

# %%
# an illstruation of Gabor filter+HOG
image = train_images[78]
kernel = np.real(gabor_kernel(frequency=0.5, 
                              theta=2/4*np.pi,
                              sigma_x=1, sigma_y=1))

filtered_image = cv2.filter2D(image, cv2.CV_8UC3, kernel)

HOG_features, HOG_image = hog(filtered_image, 
                              orientations=4, 
                              pixels_per_cell=(8, 8),
                              cells_per_block=(6, 6), 
                              visualize=True)


# Display the original and a filtered image side by side
plt.figure(figsize=(15, 5))  # Adjust figure size if needed

# Original image
plt.subplot(1, 3, 1)  # 1 row, 2 columns, 1st subplot
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Filtered image (select one from filtered_images, e.g., the first one)
plt.subplot(1, 3, 2)  # 1 row, 2 columns, 2nd subplot
plt.imshow(filtered_image, cmap='gray')  # Display the first filtered image
plt.title('Filtered Image')
plt.axis('off')

# Filtered image (select one from filtered_images, e.g., the first one)
plt.subplot(1, 3, 3)  # 1 row, 2 columns, 2nd subplot
plt.imshow(HOG_image, cmap='gray')  # Display the first filtered image
plt.title('HOG of the filtered Image')
plt.axis('off')

plt.show()

# %% [markdown]
# ### Method 1: Apply a coarse Gabor and HOG

# %%
# define the function to apply gabor filter and HOG features extraction at the same time
def Gabor_HOG(image):
    kernel = np.real(gabor_kernel(frequency=0.25, 
                              theta=2/4*np.pi,
                              sigma_x=2, sigma_y=2))

    filtered_image = cv2.filter2D(image, cv2.CV_8UC3, kernel)

    Gabor_HOG_features = hog(filtered_image, 
                              orientations=4, 
                              pixels_per_cell=(8, 8),
                              cells_per_block=(6, 6), 
                              visualize=False)
    return Gabor_HOG_features

# %%
# Apply the Gabor_HOG function to each image
train_images_Gabor_HOG = []
for i in range(train_images.shape[0]):
    image = train_images[i]
    features = Gabor_HOG(image)
    train_images_Gabor_HOG.append(features)
    
# Convert the list of features to a NumPy array
train_images_Gabor_HOG = np.array(train_images_Gabor_HOG)

print(train_images_Gabor_HOG.shape)  # Print the shape of the resulting feature array


test_images_Gabor_HOG = []
for i in range(test_images.shape[0]):
    image = test_images[i]
    features = Gabor_HOG(image)
    test_images_Gabor_HOG.append(features)
    
# Convert the list of features to a NumPy array
test_images_Gabor_HOG = np.array(test_images_Gabor_HOG)

print(test_images_Gabor_HOG.shape)  # Print the shape of the resulting feature array
# Out:
# (28709, 144)
# (7178, 144)

# %%
# Assuming you have your data as X and y

def auto_xgboost(
    X,
    y,
    n_estimators=200,
    random_state=2024,
    cv=10
    ):
    # 1. Parameter grid
    param_grid = {
        'max_depth': [5, 10, 20, 50],
        'learning_rate': [0.01, 0.05, 0.1],
        'colsample_bytree': [0.1, 0.2, 0.5]
        # 'min_child_weight': [1, 2, 5, 10, 20]
        # 'gamma': [0, 0.1],
        # 'subsample': [0.8, 1.0]
    }
    # 2. Create base model
    xgb_model = XGBClassifier(
        objective='multi:softmax',
        n_estimators= n_estimators,
        subsample = 0.4, # randomly sample 30% of the training data for each tree, avoid overfitting
        # use_label_encoder=False,
        eval_metric='merror',
        random_state=random_state,
        n_jobs = 1
    )

    # 3. Setup StratifiedKFold
    skf = StratifiedKFold(
        n_splits=cv,
        shuffle=True,
        random_state=random_state
    )

    # 4. Setup GridSearchCV
    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        cv=skf,
        scoring='accuracy',
        n_jobs=-1, # use all the CPU cores
        verbose=2  # detailed output monitoring progress updates
    )

    # 5. Scale the features
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 6. Fit the model
    grid_search.fit(X_scaled, y_encoded)

    # 7. Best model
    best_model = grid_search.best_estimator_
    
    # 8. Best params
    best_par = grid_search.best_params_
    
    # 9. Best CV score
    best_score = grid_search.best_score_

    # 10. Feature importance
    feature_importance = pd.DataFrame({
        'feature': [f'feature_{i}' for i in range(X.shape[1])],
        'importance': best_model.feature_importances_
    })
    feature_importance = feature_importance.sort_values('importance', ascending=False)
    
    # compile and return the results
    results = {
        'best_params': best_par,
        'best_score': best_score,
        'best_model': best_model,
        'feature_importance': feature_importance
    }

    return results, grid_search

# %%
start_time = time()

XGB_result, grid_search = auto_xgboost(X=train_images_Gabor_HOG, y=train_Class)
  
end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# Runtime: 118.72640028397242 mins

# %%
# loop through and print the results
for key, value in XGB_result.items():
    print(f"{key}: \n {value}")
# Out:
# best_params:
#  {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 20}
# best_score:
#  0.44686324982372083
# best_model:
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=20,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=1, num_parallel_tree=None, objective='multi:softmax', ...)
# feature_importance:
#           feature  importance
# 113  feature_113    0.011649
# 106  feature_106    0.009893
# 129  feature_129    0.009672
# 29    feature_29    0.009321
# 109  feature_109    0.009174
# ..           ...         ...
# 85    feature_85    0.006261
# 92    feature_92    0.006258
# 67    feature_67    0.006233
# 16    feature_16    0.006167
# 96    feature_96    0.006149
#
# [144 rows x 2 columns]

# %%
start_time = time()

# work on the test data set
# fit with the best model with 5000 trees
scaler = StandardScaler()
scaler.fit(train_images_Gabor_HOG)
train_images_scaled = scaler.transform(train_images_Gabor_HOG)
test_images_scaled = scaler.transform(test_images_Gabor_HOG)

# encode the classes
label_encoder = LabelEncoder()
label_encoder.fit(train_Class)
train_Class_encoded = label_encoder.transform(train_Class)
test_Class_encoded = label_encoder.transform(test_Class)

X_ttrain, X_val, y_ttrain, y_val = train_test_split(train_images_scaled, train_Class_encoded, 
                                                  test_size=0.1, random_state=2024, stratify=train_Class_encoded)
    
    
xgb = XGBClassifier(max_depth=20, learning_rate=0.05,
                       random_state=2024, subsample = 0.5, n_estimators=5000, colsample_bytree=0.5,
                       objective='multi:softmax', eval_metric='merror', early_stopping_rounds=500)
xgb.fit(X_ttrain, y_ttrain, eval_set=[(X_val, y_val)])
# xgb.fit(train_images_scaled, train_Class_encoded)
train_Class_pred = xgb.predict(train_images_scaled)
test_Class_pred = xgb.predict(test_images_scaled)

end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# [0]	validation_0-merror:0.72901
# [1]	validation_0-merror:0.69488
# [2]	validation_0-merror:0.67503
# [3]	validation_0-merror:0.65587
# [4]	validation_0-merror:0.64855
# [5]	validation_0-merror:0.64786
# [6]	validation_0-merror:0.63950
# [7]	validation_0-merror:0.63393
# [8]	validation_0-merror:0.62905
# [9]	validation_0-merror:0.62313
# [10]	validation_0-merror:0.62104
# [11]	validation_0-merror:0.60989
# [12]	validation_0-merror:0.60780
# [13]	validation_0-merror:0.60676
# [14]	validation_0-merror:0.60745
# [15]	validation_0-merror:0.60676
# [16]	validation_0-merror:0.60571
# [17]	validation_0-merror:0.61372
# [18]	validation_0-merror:0.61407
# [19]	validation_0-merror:0.61372
# [20]	validation_0-merror:0.61442
# [21]	validation_0-merror:0.61198
# [22]	validation_0-merror:0.60850
# [23]	validation_0-merror:0.60641
# [24]	validation_0-merror:0.60327
# [25]	validation_0-merror:0.60362
# [26]	validation_0-merror:0.60780
# [27]	validation_0-merror:0.60258
# [28]	validation_0-merror:0.60014
# [29]	validation_0-merror:0.59840
# [30]	validation_0-merror:0.59875
# [31]	validation_0-merror:0.59596
# [32]	validation_0-merror:0.60049
# [33]	validation_0-merror:0.59875
# [34]	validation_0-merror:0.59526
# [35]	validation_0-merror:0.59213
# [36]	validation_0-merror:0.59596
# [37]	validation_0-merror:0.59735
# [38]	validation_0-merror:0.59631
# [39]	validation_0-merror:0.59596
# [40]	validation_0-merror:0.59526
# [41]	validation_0-merror:0.59979
# [42]	validation_0-merror:0.59805
# [43]	validation_0-merror:0.59596
# [44]	validation_0-merror:0.59700
# [45]	validation_0-merror:0.59596
# [46]	validation_0-merror:0.59457
# [47]	validation_0-merror:0.59735
# [48]	validation_0-merror:0.59108
# [49]	validation_0-merror:0.59317
# [50]	validation_0-merror:0.59387
# [51]	validation_0-merror:0.59004
# [52]	validation_0-merror:0.59039
# [53]	validation_0-merror:0.58795
# [54]	validation_0-merror:0.58934
# [55]	validation_0-merror:0.58621
# [56]	validation_0-merror:0.58760
# [57]	validation_0-merror:0.58656
# [58]	validation_0-merror:0.58690
# [59]	validation_0-merror:0.58412
# [60]	validation_0-merror:0.58377
# [61]	validation_0-merror:0.58690
# [62]	validation_0-merror:0.58795
# [63]	validation_0-merror:0.58342
# [64]	validation_0-merror:0.58447
# [65]	validation_0-merror:0.58760
# [66]	validation_0-merror:0.58690
# [67]	validation_0-merror:0.58481
# [68]	validation_0-merror:0.58516
# [69]	validation_0-merror:0.58621
# [70]	validation_0-merror:0.58551
# [71]	validation_0-merror:0.58272
# [72]	validation_0-merror:0.58168
# [73]	validation_0-merror:0.58168
# [74]	validation_0-merror:0.58133
# [75]	validation_0-merror:0.58272
# [76]	validation_0-merror:0.58412
# [77]	validation_0-merror:0.58203
# [78]	validation_0-merror:0.58168
# [79]	validation_0-merror:0.58203
# [80]	validation_0-merror:0.58272
# [81]	validation_0-merror:0.58203
# [82]	validation_0-merror:0.58098
# [83]	validation_0-merror:0.58063
# [84]	validation_0-merror:0.58307
# [85]	validation_0-merror:0.58551
# [86]	validation_0-merror:0.58586
# [87]	validation_0-merror:0.58377
# [88]	validation_0-merror:0.58098
# [89]	validation_0-merror:0.58272
# [90]	validation_0-merror:0.58307
# [91]	validation_0-merror:0.58133
# [92]	validation_0-merror:0.57924
# [93]	validation_0-merror:0.58029
# [94]	validation_0-merror:0.57854
# [95]	validation_0-merror:0.57994
# [96]	validation_0-merror:0.58203
# [97]	validation_0-merror:0.58063
# [98]	validation_0-merror:0.57889
# [99]	validation_0-merror:0.57959
# [100]	validation_0-merror:0.57750
# [101]	validation_0-merror:0.57715
# [102]	validation_0-merror:0.57715
# [103]	validation_0-merror:0.57750
# [104]	validation_0-merror:0.57820
# [105]	validation_0-merror:0.57611
# [106]	validation_0-merror:0.57541
# [107]	validation_0-merror:0.57332
# [108]	validation_0-merror:0.57471
# [109]	validation_0-merror:0.57297
# [110]	validation_0-merror:0.57402
# [111]	validation_0-merror:0.57611
# [112]	validation_0-merror:0.57715
# [113]	validation_0-merror:0.57541
# [114]	validation_0-merror:0.57402
# [115]	validation_0-merror:0.57436
# [116]	validation_0-merror:0.57227
# [117]	validation_0-merror:0.57297
# [118]	validation_0-merror:0.57227
# [119]	validation_0-merror:0.57193
# [120]	validation_0-merror:0.57088
# [121]	validation_0-merror:0.57262
# [122]	validation_0-merror:0.57262
# [123]	validation_0-merror:0.57262
# [124]	validation_0-merror:0.57402
# [125]	validation_0-merror:0.57227
# [126]	validation_0-merror:0.57262
# [127]	validation_0-merror:0.57158
# [128]	validation_0-merror:0.57158
# [129]	validation_0-merror:0.57123
# [130]	validation_0-merror:0.57088
# [131]	validation_0-merror:0.57088
# [132]	validation_0-merror:0.57018
# [133]	validation_0-merror:0.56809
# [134]	validation_0-merror:0.56949
# [135]	validation_0-merror:0.57053
# [136]	validation_0-merror:0.56949
# [137]	validation_0-merror:0.57053
# [138]	validation_0-merror:0.57158
# [139]	validation_0-merror:0.56984
# [140]	validation_0-merror:0.57018
# [141]	validation_0-merror:0.57262
# [142]	validation_0-merror:0.57262
# [143]	validation_0-merror:0.56949
# [144]	validation_0-merror:0.57227
# [145]	validation_0-merror:0.57227
# [146]	validation_0-merror:0.57158
# [147]	validation_0-merror:0.57053
# [148]	validation_0-merror:0.57123
# [149]	validation_0-merror:0.57123
# [150]	validation_0-merror:0.57018
# [151]	validation_0-merror:0.56740
# [152]	validation_0-merror:0.57053
# [153]	validation_0-merror:0.56984
# [154]	validation_0-merror:0.56775
# [155]	validation_0-merror:0.56740
# [156]	validation_0-merror:0.56949
# [157]	validation_0-merror:0.56635
# [158]	validation_0-merror:0.56740
# [159]	validation_0-merror:0.56670
# [160]	validation_0-merror:0.56635
# [161]	validation_0-merror:0.56809
# [162]	validation_0-merror:0.56809
# [163]	validation_0-merror:0.56844
# [164]	validation_0-merror:0.56705
# [165]	validation_0-merror:0.57018
# [166]	validation_0-merror:0.57018
# [167]	validation_0-merror:0.56670
# [168]	validation_0-merror:0.56600
# [169]	validation_0-merror:0.56531
# [170]	validation_0-merror:0.56531
# [171]	validation_0-merror:0.56531
# [172]	validation_0-merror:0.56635
# [173]	validation_0-merror:0.56600
# [174]	validation_0-merror:0.56670
# [175]	validation_0-merror:0.56461
# [176]	validation_0-merror:0.56392
# [177]	validation_0-merror:0.56496
# [178]	validation_0-merror:0.56496
# [179]	validation_0-merror:0.56566
# [180]	validation_0-merror:0.56357
# [181]	validation_0-merror:0.56357
# [182]	validation_0-merror:0.56322
# [183]	validation_0-merror:0.56183
# [184]	validation_0-merror:0.56322
# [185]	validation_0-merror:0.56252
# [186]	validation_0-merror:0.56148
# [187]	validation_0-merror:0.56357
# [188]	validation_0-merror:0.56217
# [189]	validation_0-merror:0.56217
# [190]	validation_0-merror:0.56008
# [191]	validation_0-merror:0.55974
# [192]	validation_0-merror:0.56113
# [193]	validation_0-merror:0.56008
# [194]	validation_0-merror:0.56043
# [195]	validation_0-merror:0.56043
# [196]	validation_0-merror:0.56078
# [197]	validation_0-merror:0.56148
# [198]	validation_0-merror:0.56043
# [199]	validation_0-merror:0.56148
# [200]	validation_0-merror:0.56043
# [201]	validation_0-merror:0.56113
# [202]	validation_0-merror:0.56148
# [203]	validation_0-merror:0.56287
# [204]	validation_0-merror:0.56252
# [205]	validation_0-merror:0.56113
# [206]	validation_0-merror:0.55974
# [207]	validation_0-merror:0.55869
# [208]	validation_0-merror:0.55904
# [209]	validation_0-merror:0.56008
# [210]	validation_0-merror:0.55974
# [211]	validation_0-merror:0.55869
# [212]	validation_0-merror:0.55799
# [213]	validation_0-merror:0.55974
# [214]	validation_0-merror:0.56043
# [215]	validation_0-merror:0.55939
# [216]	validation_0-merror:0.55939
# [217]	validation_0-merror:0.55799
# [218]	validation_0-merror:0.55904
# [219]	validation_0-merror:0.55799
# [220]	validation_0-merror:0.55695
# [221]	validation_0-merror:0.55590
# [222]	validation_0-merror:0.55765
# [223]	validation_0-merror:0.55660
# [224]	validation_0-merror:0.55625
# [225]	validation_0-merror:0.55660
# [226]	validation_0-merror:0.55834
# [227]	validation_0-merror:0.55765
# [228]	validation_0-merror:0.55869
# [229]	validation_0-merror:0.55660
# [230]	validation_0-merror:0.55904
# [231]	validation_0-merror:0.55834
# [232]	validation_0-merror:0.55799
# [233]	validation_0-merror:0.55834
# [234]	validation_0-merror:0.55834
# [235]	validation_0-merror:0.55765
# [236]	validation_0-merror:0.55590
# [237]	validation_0-merror:0.55765
# [238]	validation_0-merror:0.55799
# [239]	validation_0-merror:0.55695
# [240]	validation_0-merror:0.55660
# [241]	validation_0-merror:0.55799
# [242]	validation_0-merror:0.55730
# [243]	validation_0-merror:0.55695
# [244]	validation_0-merror:0.55660
# [245]	validation_0-merror:0.55590
# [246]	validation_0-merror:0.55625
# [247]	validation_0-merror:0.55556
# [248]	validation_0-merror:0.55521
# [249]	validation_0-merror:0.55521
# [250]	validation_0-merror:0.55730
# [251]	validation_0-merror:0.55869
# [252]	validation_0-merror:0.55730
# [253]	validation_0-merror:0.55730
# [254]	validation_0-merror:0.55799
# [255]	validation_0-merror:0.55625
# [256]	validation_0-merror:0.55765
# [257]	validation_0-merror:0.55765
# [258]	validation_0-merror:0.55695
# [259]	validation_0-merror:0.55730
# [260]	validation_0-merror:0.55695
# [261]	validation_0-merror:0.55765
# [262]	validation_0-merror:0.55765
# [263]	validation_0-merror:0.55625
# [264]	validation_0-merror:0.55695
# [265]	validation_0-merror:0.55695
# [266]	validation_0-merror:0.55660
# [267]	validation_0-merror:0.55765
# [268]	validation_0-merror:0.55799
# [269]	validation_0-merror:0.55660
# [270]	validation_0-merror:0.55556
# [271]	validation_0-merror:0.55451
# [272]	validation_0-merror:0.55451
# [273]	validation_0-merror:0.55381
# [274]	validation_0-merror:0.55521
# [275]	validation_0-merror:0.55521
# [276]	validation_0-merror:0.55486
# [277]	validation_0-merror:0.55486
# [278]	validation_0-merror:0.55416
# [279]	validation_0-merror:0.55451
# [280]	validation_0-merror:0.55590
# [281]	validation_0-merror:0.55590
# [282]	validation_0-merror:0.55451
# [283]	validation_0-merror:0.55521
# [284]	validation_0-merror:0.55451
# [285]	validation_0-merror:0.55416
# [286]	validation_0-merror:0.55277
# [287]	validation_0-merror:0.55381
# [288]	validation_0-merror:0.55347
# [289]	validation_0-merror:0.55381
# [290]	validation_0-merror:0.55381
# [291]	validation_0-merror:0.55347
# [292]	validation_0-merror:0.55381
# [293]	validation_0-merror:0.55416
# [294]	validation_0-merror:0.55347
# [295]	validation_0-merror:0.55347
# [296]	validation_0-merror:0.55347
# [297]	validation_0-merror:0.55312
# [298]	validation_0-merror:0.55381
# [299]	validation_0-merror:0.55312
# [300]	validation_0-merror:0.55312
# [301]	validation_0-merror:0.55381
# [302]	validation_0-merror:0.55416
# [303]	validation_0-merror:0.55451
# [304]	validation_0-merror:0.55381
# [305]	validation_0-merror:0.55416
# [306]	validation_0-merror:0.55312
# [307]	validation_0-merror:0.55381
# [308]	validation_0-merror:0.55381
# [309]	validation_0-merror:0.55347
# [310]	validation_0-merror:0.55347
# [311]	validation_0-merror:0.55277
# [312]	validation_0-merror:0.55277
# [313]	validation_0-merror:0.55416
# [314]	validation_0-merror:0.55381
# [315]	validation_0-merror:0.55486
# [316]	validation_0-merror:0.55381
# [317]	validation_0-merror:0.55381
# [318]	validation_0-merror:0.55381
# [319]	validation_0-merror:0.55312
# [320]	validation_0-merror:0.55381
# [321]	validation_0-merror:0.55138
# [322]	validation_0-merror:0.55068
# [323]	validation_0-merror:0.55138
# [324]	validation_0-merror:0.54998
# [325]	validation_0-merror:0.54929
# [326]	validation_0-merror:0.54998
# [327]	validation_0-merror:0.54998
# [328]	validation_0-merror:0.55033
# [329]	validation_0-merror:0.55033
# [330]	validation_0-merror:0.54998
# [331]	validation_0-merror:0.54998
# [332]	validation_0-merror:0.54963
# [333]	validation_0-merror:0.55033
# [334]	validation_0-merror:0.54963
# [335]	validation_0-merror:0.54998
# [336]	validation_0-merror:0.55033
# [337]	validation_0-merror:0.55172
# [338]	validation_0-merror:0.55068
# [339]	validation_0-merror:0.54859
# [340]	validation_0-merror:0.54998
# [341]	validation_0-merror:0.55172
# [342]	validation_0-merror:0.55103
# [343]	validation_0-merror:0.55103
# [344]	validation_0-merror:0.55207
# [345]	validation_0-merror:0.55172
# [346]	validation_0-merror:0.55033
# [347]	validation_0-merror:0.54963
# [348]	validation_0-merror:0.55172
# [349]	validation_0-merror:0.55312
# [350]	validation_0-merror:0.55277
# [351]	validation_0-merror:0.55138
# [352]	validation_0-merror:0.55242
# [353]	validation_0-merror:0.55277
# [354]	validation_0-merror:0.55068
# [355]	validation_0-merror:0.55103
# [356]	validation_0-merror:0.54998
# [357]	validation_0-merror:0.55068
# [358]	validation_0-merror:0.55103
# [359]	validation_0-merror:0.55172
# [360]	validation_0-merror:0.55103
# [361]	validation_0-merror:0.55068
# [362]	validation_0-merror:0.55068
# [363]	validation_0-merror:0.55172
# [364]	validation_0-merror:0.55068
# [365]	validation_0-merror:0.54929
# [366]	validation_0-merror:0.54929
# [367]	validation_0-merror:0.54859
# [368]	validation_0-merror:0.54859
# [369]	validation_0-merror:0.54894
# [370]	validation_0-merror:0.54789
# [371]	validation_0-merror:0.54859
# [372]	validation_0-merror:0.54929
# [373]	validation_0-merror:0.55033
# [374]	validation_0-merror:0.55172
# [375]	validation_0-merror:0.54929
# [376]	validation_0-merror:0.54998
# [377]	validation_0-merror:0.54998
# [378]	validation_0-merror:0.55103
# [379]	validation_0-merror:0.55033
# [380]	validation_0-merror:0.55138
# [381]	validation_0-merror:0.54963
# [382]	validation_0-merror:0.55138
# [383]	validation_0-merror:0.55068
# [384]	validation_0-merror:0.55207
# [385]	validation_0-merror:0.55068
# [386]	validation_0-merror:0.55068
# [387]	validation_0-merror:0.55103
# [388]	validation_0-merror:0.55103
# [389]	validation_0-merror:0.54963
# [390]	validation_0-merror:0.55068
# [391]	validation_0-merror:0.54963
# [392]	validation_0-merror:0.55033
# [393]	validation_0-merror:0.55068
# [394]	validation_0-merror:0.55033
# [395]	validation_0-merror:0.55103
# [396]	validation_0-merror:0.54998
# [397]	validation_0-merror:0.55033
# [398]	validation_0-merror:0.55068
# [399]	validation_0-merror:0.55068
# [400]	validation_0-merror:0.54998
# [401]	validation_0-merror:0.54929
# [402]	validation_0-merror:0.54859
# [403]	validation_0-merror:0.54963
# [404]	validation_0-merror:0.54824
# [405]	validation_0-merror:0.54859
# [406]	validation_0-merror:0.54894
# [407]	validation_0-merror:0.55033
# [408]	validation_0-merror:0.54929
# [409]	validation_0-merror:0.54859
# [410]	validation_0-merror:0.54963
# [411]	validation_0-merror:0.54963
# [412]	validation_0-merror:0.54929
# [413]	validation_0-merror:0.54859
# [414]	validation_0-merror:0.54894
# [415]	validation_0-merror:0.54963
# [416]	validation_0-merror:0.54929
# [417]	validation_0-merror:0.54894
# [418]	validation_0-merror:0.54894
# [419]	validation_0-merror:0.54929
# [420]	validation_0-merror:0.54894
# [421]	validation_0-merror:0.54859
# [422]	validation_0-merror:0.54894
# [423]	validation_0-merror:0.54929
# [424]	validation_0-merror:0.54929
# [425]	validation_0-merror:0.54963
# [426]	validation_0-merror:0.54859
# [427]	validation_0-merror:0.54963
# [428]	validation_0-merror:0.54963
# [429]	validation_0-merror:0.54859
# [430]	validation_0-merror:0.54894
# [431]	validation_0-merror:0.55033
# [432]	validation_0-merror:0.55103
# [433]	validation_0-merror:0.55103
# [434]	validation_0-merror:0.54998
# [435]	validation_0-merror:0.54894
# [436]	validation_0-merror:0.54859
# [437]	validation_0-merror:0.55033
# [438]	validation_0-merror:0.55033
# [439]	validation_0-merror:0.54859
# [440]	validation_0-merror:0.54789
# [441]	validation_0-merror:0.54894
# [442]	validation_0-merror:0.54824
# [443]	validation_0-merror:0.54894
# [444]	validation_0-merror:0.54894
# [445]	validation_0-merror:0.54963
# [446]	validation_0-merror:0.55068
# [447]	validation_0-merror:0.55207
# [448]	validation_0-merror:0.55103
# [449]	validation_0-merror:0.54963
# [450]	validation_0-merror:0.54963
# [451]	validation_0-merror:0.54859
# [452]	validation_0-merror:0.54929
# [453]	validation_0-merror:0.54929
# [454]	validation_0-merror:0.54789
# [455]	validation_0-merror:0.54929
# [456]	validation_0-merror:0.54824
# [457]	validation_0-merror:0.54824
# [458]	validation_0-merror:0.54685
# [459]	validation_0-merror:0.54650
# [460]	validation_0-merror:0.54789
# [461]	validation_0-merror:0.54650
# [462]	validation_0-merror:0.54754
# [463]	validation_0-merror:0.54650
# [464]	validation_0-merror:0.54685
# [465]	validation_0-merror:0.54789
# [466]	validation_0-merror:0.54859
# [467]	validation_0-merror:0.54754
# [468]	validation_0-merror:0.54789
# [469]	validation_0-merror:0.54789
# [470]	validation_0-merror:0.54685
# [471]	validation_0-merror:0.54720
# [472]	validation_0-merror:0.54615
# [473]	validation_0-merror:0.54754
# [474]	validation_0-merror:0.54615
# [475]	validation_0-merror:0.54650
# [476]	validation_0-merror:0.54650
# [477]	validation_0-merror:0.54511
# [478]	validation_0-merror:0.54511
# [479]	validation_0-merror:0.54650
# [480]	validation_0-merror:0.54545
# [481]	validation_0-merror:0.54580
# [482]	validation_0-merror:0.54650
# [483]	validation_0-merror:0.54650
# [484]	validation_0-merror:0.54650
# [485]	validation_0-merror:0.54545
# [486]	validation_0-merror:0.54650
# [487]	validation_0-merror:0.54511
# [488]	validation_0-merror:0.54580
# [489]	validation_0-merror:0.54650
# [490]	validation_0-merror:0.54650
# [491]	validation_0-merror:0.54580
# [492]	validation_0-merror:0.54545
# [493]	validation_0-merror:0.54615
# [494]	validation_0-merror:0.54580
# [495]	validation_0-merror:0.54580
# [496]	validation_0-merror:0.54476
# [497]	validation_0-merror:0.54476
# [498]	validation_0-merror:0.54441
# [499]	validation_0-merror:0.54406
# [500]	validation_0-merror:0.54406
# [501]	validation_0-merror:0.54371
# [502]	validation_0-merror:0.54441
# [503]	validation_0-merror:0.54371
# [504]	validation_0-merror:0.54406
# [505]	validation_0-merror:0.54406
# [506]	validation_0-merror:0.54441
# [507]	validation_0-merror:0.54476
# [508]	validation_0-merror:0.54511
# [509]	validation_0-merror:0.54511
# [510]	validation_0-merror:0.54545
# [511]	validation_0-merror:0.54615
# [512]	validation_0-merror:0.54615
# [513]	validation_0-merror:0.54476
# [514]	validation_0-merror:0.54476
# [515]	validation_0-merror:0.54441
# [516]	validation_0-merror:0.54371
# [517]	validation_0-merror:0.54371
# [518]	validation_0-merror:0.54336
# [519]	validation_0-merror:0.54302
# [520]	validation_0-merror:0.54371
# [521]	validation_0-merror:0.54336
# [522]	validation_0-merror:0.54371
# [523]	validation_0-merror:0.54302
# [524]	validation_0-merror:0.54336
# [525]	validation_0-merror:0.54232
# [526]	validation_0-merror:0.54336
# [527]	validation_0-merror:0.54197
# [528]	validation_0-merror:0.54336
# [529]	validation_0-merror:0.54302
# [530]	validation_0-merror:0.54406
# [531]	validation_0-merror:0.54406
# [532]	validation_0-merror:0.54371
# [533]	validation_0-merror:0.54302
# [534]	validation_0-merror:0.54232
# [535]	validation_0-merror:0.54232
# [536]	validation_0-merror:0.54302
# [537]	validation_0-merror:0.54267
# [538]	validation_0-merror:0.54197
# [539]	validation_0-merror:0.54162
# [540]	validation_0-merror:0.54127
# [541]	validation_0-merror:0.54162
# [542]	validation_0-merror:0.54093
# [543]	validation_0-merror:0.54058
# [544]	validation_0-merror:0.53988
# [545]	validation_0-merror:0.54093
# [546]	validation_0-merror:0.54023
# [547]	validation_0-merror:0.54093
# [548]	validation_0-merror:0.54093
# [549]	validation_0-merror:0.54127
# [550]	validation_0-merror:0.54093
# [551]	validation_0-merror:0.54127
# [552]	validation_0-merror:0.53988
# [553]	validation_0-merror:0.54232
# [554]	validation_0-merror:0.54267
# [555]	validation_0-merror:0.54302
# [556]	validation_0-merror:0.54267
# [557]	validation_0-merror:0.54302
# [558]	validation_0-merror:0.54406
# [559]	validation_0-merror:0.54371
# [560]	validation_0-merror:0.54371
# [561]	validation_0-merror:0.54267
# [562]	validation_0-merror:0.54232
# [563]	validation_0-merror:0.54267
# [564]	validation_0-merror:0.54232
# [565]	validation_0-merror:0.54302
# [566]	validation_0-merror:0.54197
# [567]	validation_0-merror:0.54162
# [568]	validation_0-merror:0.54162
# [569]	validation_0-merror:0.54162
# [570]	validation_0-merror:0.54093
# [571]	validation_0-merror:0.54093
# [572]	validation_0-merror:0.54058
# [573]	validation_0-merror:0.54058
# [574]	validation_0-merror:0.54093
# [575]	validation_0-merror:0.54127
# [576]	validation_0-merror:0.54162
# [577]	validation_0-merror:0.54162
# [578]	validation_0-merror:0.54127
# [579]	validation_0-merror:0.54058
# [580]	validation_0-merror:0.54093
# [581]	validation_0-merror:0.54162
# [582]	validation_0-merror:0.54197
# [583]	validation_0-merror:0.54162
# [584]	validation_0-merror:0.54093
# [585]	validation_0-merror:0.54197
# [586]	validation_0-merror:0.54162
# [587]	validation_0-merror:0.54127
# [588]	validation_0-merror:0.54162
# [589]	validation_0-merror:0.54197
# [590]	validation_0-merror:0.54197
# [591]	validation_0-merror:0.54162
# [592]	validation_0-merror:0.54197
# [593]	validation_0-merror:0.54162
# [594]	validation_0-merror:0.54162
# [595]	validation_0-merror:0.54093
# [596]	validation_0-merror:0.54162
# [597]	validation_0-merror:0.54127
# [598]	validation_0-merror:0.54058
# [599]	validation_0-merror:0.54058
# [600]	validation_0-merror:0.54093
# [601]	validation_0-merror:0.54162
# [602]	validation_0-merror:0.54232
# [603]	validation_0-merror:0.54162
# [604]	validation_0-merror:0.54197
# [605]	validation_0-merror:0.54162
# [606]	validation_0-merror:0.54127
# [607]	validation_0-merror:0.54127
# [608]	validation_0-merror:0.54127
# [609]	validation_0-merror:0.54127
# [610]	validation_0-merror:0.54127
# [611]	validation_0-merror:0.54093
# [612]	validation_0-merror:0.54127
# [613]	validation_0-merror:0.54093
# [614]	validation_0-merror:0.54127
# [615]	validation_0-merror:0.54093
# [616]	validation_0-merror:0.54093
# [617]	validation_0-merror:0.54093
# [618]	validation_0-merror:0.54023
# [619]	validation_0-merror:0.54023
# [620]	validation_0-merror:0.53988
# [621]	validation_0-merror:0.54023
# [622]	validation_0-merror:0.54093
# [623]	validation_0-merror:0.54058
# [624]	validation_0-merror:0.54162
# [625]	validation_0-merror:0.54197
# [626]	validation_0-merror:0.54162
# [627]	validation_0-merror:0.54197
# [628]	validation_0-merror:0.54162
# [629]	validation_0-merror:0.54162
# [630]	validation_0-merror:0.54197
# [631]	validation_0-merror:0.54197
# [632]	validation_0-merror:0.54162
# [633]	validation_0-merror:0.54197
# [634]	validation_0-merror:0.54232
# [635]	validation_0-merror:0.54232
# [636]	validation_0-merror:0.54127
# [637]	validation_0-merror:0.54232
# [638]	validation_0-merror:0.54197
# [639]	validation_0-merror:0.54197
# [640]	validation_0-merror:0.54197
# [641]	validation_0-merror:0.54162
# [642]	validation_0-merror:0.54127
# [643]	validation_0-merror:0.54162
# [644]	validation_0-merror:0.54232
# [645]	validation_0-merror:0.54127
# [646]	validation_0-merror:0.54197
# [647]	validation_0-merror:0.54162
# [648]	validation_0-merror:0.54336
# [649]	validation_0-merror:0.54371
# [650]	validation_0-merror:0.54371
# [651]	validation_0-merror:0.54302
# [652]	validation_0-merror:0.54302
# [653]	validation_0-merror:0.54232
# [654]	validation_0-merror:0.54232
# [655]	validation_0-merror:0.54232
# [656]	validation_0-merror:0.54267
# [657]	validation_0-merror:0.54232
# [658]	validation_0-merror:0.54267
# [659]	validation_0-merror:0.54302
# [660]	validation_0-merror:0.54302
# [661]	validation_0-merror:0.54336
# [662]	validation_0-merror:0.54232
# [663]	validation_0-merror:0.54197
# [664]	validation_0-merror:0.54336
# [665]	validation_0-merror:0.54232
# [666]	validation_0-merror:0.54232
# [667]	validation_0-merror:0.54336
# [668]	validation_0-merror:0.54197
# [669]	validation_0-merror:0.54267
# [670]	validation_0-merror:0.54197
# [671]	validation_0-merror:0.54232
# [672]	validation_0-merror:0.54197
# [673]	validation_0-merror:0.54267
# [674]	validation_0-merror:0.54302
# [675]	validation_0-merror:0.54162
# [676]	validation_0-merror:0.54127
# [677]	validation_0-merror:0.54197
# [678]	validation_0-merror:0.54162
# [679]	validation_0-merror:0.54093
# [680]	validation_0-merror:0.54162
# [681]	validation_0-merror:0.54162
# [682]	validation_0-merror:0.54127
# [683]	validation_0-merror:0.54127
# [684]	validation_0-merror:0.54127
# [685]	validation_0-merror:0.54162
# [686]	validation_0-merror:0.54162
# [687]	validation_0-merror:0.54162
# [688]	validation_0-merror:0.54127
# [689]	validation_0-merror:0.54023
# [690]	validation_0-merror:0.54093
# [691]	validation_0-merror:0.54058
# [692]	validation_0-merror:0.54127
# [693]	validation_0-merror:0.54023
# [694]	validation_0-merror:0.54058
# [695]	validation_0-merror:0.54023
# [696]	validation_0-merror:0.54023
# [697]	validation_0-merror:0.54058
# [698]	validation_0-merror:0.54058
# [699]	validation_0-merror:0.53884
# [700]	validation_0-merror:0.53953
# [701]	validation_0-merror:0.53988
# [702]	validation_0-merror:0.54093
# [703]	validation_0-merror:0.53918
# [704]	validation_0-merror:0.53884
# [705]	validation_0-merror:0.53988
# [706]	validation_0-merror:0.53884
# [707]	validation_0-merror:0.53953
# [708]	validation_0-merror:0.53849
# [709]	validation_0-merror:0.53849
# [710]	validation_0-merror:0.53884
# [711]	validation_0-merror:0.53779
# [1703]	validation_0-merror:0.53466
# [1704]	validation_0-merror:0.53501
# [1705]	validation_0-merror:0.53501
# [1706]	validation_0-merror:0.53466
# [1707]	validation_0-merror:0.53570
# [1708]	validation_0-merror:0.53501
# [1709]	validation_0-merror:0.53501
# [1710]	validation_0-merror:0.53466
# [1711]	validation_0-merror:0.53501
# [1712]	validation_0-merror:0.53535
# [1713]	validation_0-merror:0.53640
# [1714]	validation_0-merror:0.53535
# [1715]	validation_0-merror:0.53501
# [1716]	validation_0-merror:0.53570
# [1717]	validation_0-merror:0.53535
# [1718]	validation_0-merror:0.53570
# [1719]	validation_0-merror:0.53466
# [1720]	validation_0-merror:0.53396
# [1721]	validation_0-merror:0.53431
# [1722]	validation_0-merror:0.53466
# [1723]	validation_0-merror:0.53431
# [1724]	validation_0-merror:0.53396
# [1725]	validation_0-merror:0.53466
# [1726]	validation_0-merror:0.53466
# [1727]	validation_0-merror:0.53501
# [1728]	validation_0-merror:0.53535
# [1729]	validation_0-merror:0.53501
# [1730]	validation_0-merror:0.53570
# [1731]	validation_0-merror:0.53501
# [1732]	validation_0-merror:0.53640
# [1733]	validation_0-merror:0.53640
# [1734]	validation_0-merror:0.53535
# [1735]	validation_0-merror:0.53535
# [1736]	validation_0-merror:0.53535
# [1737]	validation_0-merror:0.53501
# [1738]	validation_0-merror:0.53535
# [1739]	validation_0-merror:0.53570
# [1740]	validation_0-merror:0.53570
# [1741]	validation_0-merror:0.53675
# [1742]	validation_0-merror:0.53744
# [1743]	validation_0-merror:0.53710
# [1744]	validation_0-merror:0.53710
# [1745]	validation_0-merror:0.53779
# [1746]	validation_0-merror:0.53744
# [1747]	validation_0-merror:0.53710
# [1748]	validation_0-merror:0.53744
# [1749]	validation_0-merror:0.53779
# [1750]	validation_0-merror:0.53744
# Runtime: 2.2846344073613483 mins

# %%
# train accuracy
print(accuracy_score(train_Class_encoded, train_Class_pred))
        
# classification_report
print(classification_report(train_Class_encoded, train_Class_pred))
# Out:
# 0.9452436518165035
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      3995
#            1       1.00      0.92      0.96       436
#            2       0.97      0.92      0.94      4097
#            3       0.93      0.98      0.95      7215
#            4       0.94      0.94      0.94      4965
#            5       0.93      0.93      0.93      4830
#            6       0.96      0.95      0.96      3171
#
#     accuracy                           0.95     28709
#    macro avg       0.96      0.94      0.95     28709
# weighted avg       0.95      0.95      0.95     28709

# %%
# train accuracy
print(accuracy_score(test_Class_encoded, test_Class_pred))
        
# classification_report
print(classification_report(test_Class_encoded, test_Class_pred))
# Out:
# 0.4657286152131513
#               precision    recall  f1-score   support
#
#            0       0.42      0.29      0.35       958
#            1       0.97      0.28      0.43       111
#            2       0.42      0.24      0.31      1024
#            3       0.51      0.79      0.62      1774
#            4       0.40      0.39      0.39      1233
#            5       0.36      0.35      0.35      1247
#            6       0.64      0.57      0.60       831
#
#     accuracy                           0.47      7178
#    macro avg       0.53      0.42      0.44      7178
# weighted avg       0.46      0.47      0.45      7178

# %% [markdown]
# ### Method 2: Apply a much finer Gabor + HOG + PCA

# %%
# a finer gabor filter and HOG features extraction
def Gabor_HOG2(image):
    kernel = np.real(gabor_kernel(frequency=0.25, 
                              theta=2/4*np.pi,
                              sigma_x=1, sigma_y=1))

    filtered_image = cv2.filter2D(image, cv2.CV_8UC3, kernel)

    Gabor_HOG_features = hog(filtered_image, 
                              orientations=8, 
                              pixels_per_cell=(4, 4),
                              cells_per_block=(2, 2), 
                              visualize=False)
    return Gabor_HOG_features

# %%
# Apply the Gabor_HOG function to each image
train2_images_Gabor_HOG = []
for i in range(train_images.shape[0]):
    image = train_images[i]
    features = Gabor_HOG2(image)
    train2_images_Gabor_HOG.append(features)
    
# Convert the list of features to a NumPy array
train2_images_Gabor_HOG = np.array(train2_images_Gabor_HOG)

print(train2_images_Gabor_HOG.shape)  # Print the shape of the resulting feature array


test2_images_Gabor_HOG = []
for i in range(test_images.shape[0]):
    image = test_images[i]
    features = Gabor_HOG2(image)
    test2_images_Gabor_HOG.append(features)
    
# Convert the list of features to a NumPy array
test2_images_Gabor_HOG = np.array(test2_images_Gabor_HOG)

print(test2_images_Gabor_HOG.shape)  # Print the shape of the resulting feature array
# Out:
# (28709, 3872)
# (7178, 3872)

# %%
from sklearn.decomposition import PCA
# Standardize the data and PCA
scaler = StandardScaler()
scaler.fit(train2_images_Gabor_HOG)
train2_images_scaled = scaler.transform(train2_images_Gabor_HOG)
test2_images_scaled = scaler.transform(test2_images_Gabor_HOG)

pca = PCA()  # Keep all components initially
principalComponents = pca.fit_transform(train2_images_scaled)

# %%
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

# Find the index where cumulative variance exceeds 0.80
n_components = len(cumulative_variance_ratio[cumulative_variance_ratio <= 0.9]) + 1 

print(f"Number of components to explain 90% variance: {n_components}")
# Out:
# Number of components to explain 90% variance: 865

# %%
# Apply PCA with the selected number of components
pca = PCA(n_components=n_components)
train2_images_pca = pca.fit_transform(train2_images_scaled)
test2_images_pca = pca.transform(test2_images_scaled)

# %%
start_time = time()

# work on the test data set
# fit with the best model with 5000 trees with earky stop rule

# encode the classes
label_encoder = LabelEncoder()
label_encoder.fit(train_Class)
train_Class_encoded = label_encoder.transform(train_Class)
test_Class_encoded = label_encoder.transform(test_Class)

X_ttrain, X_val, y_ttrain, y_val = train_test_split(train2_images_pca, train_Class_encoded, 
                                                  test_size=0.1, random_state=2024, stratify=train_Class_encoded)
    
    
xgb = XGBClassifier(max_depth=20, learning_rate=0.05,
                       random_state=2024, subsample = 0.5, n_estimators=5000, colsample_bytree=0.1,
                       objective='multi:softmax', eval_metric='merror', early_stopping_rounds=500)
xgb.fit(X_ttrain, y_ttrain, eval_set=[(X_val, y_val)])

train_Class_pred = xgb.predict(train2_images_pca)
test_Class_pred = xgb.predict(test2_images_pca)

end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# [0]	validation_0-merror:0.77429
# [1]	validation_0-merror:0.74538
# [2]	validation_0-merror:0.72379
# [3]	validation_0-merror:0.71578
# [89]	validation_0-merror:0.65482
# [90]	validation_0-merror:0.65308
# [91]	validation_0-merror:0.65343
# [92]	validation_0-merror:0.65587
# [93]	validation_0-merror:0.65378
# [94]	validation_0-merror:0.65657
# [95]	validation_0-merror:0.65517
# [96]	validation_0-merror:0.65378
# [97]	validation_0-merror:0.65482
# [98]	validation_0-merror:0.65552
# [99]	validation_0-merror:0.65413
# [100]	validation_0-merror:0.65343
# [101]	validation_0-merror:0.65239
# [102]	validation_0-merror:0.65064
# [103]	validation_0-merror:0.65169
# [104]	validation_0-merror:0.65030
# [105]	validation_0-merror:0.64855
# [106]	validation_0-merror:0.64960
# [107]	validation_0-merror:0.65064
# [108]	validation_0-merror:0.64995
# [109]	validation_0-merror:0.65064
# [110]	validation_0-merror:0.64925
# [111]	validation_0-merror:0.64890
# [112]	validation_0-merror:0.64751
# [113]	validation_0-merror:0.64577
# [114]	validation_0-merror:0.64681
# [115]	validation_0-merror:0.64716
# [116]	validation_0-merror:0.64716
# [117]	validation_0-merror:0.64646
# [118]	validation_0-merror:0.64542
# [119]	validation_0-merror:0.64507
# [120]	validation_0-merror:0.64507
# [121]	validation_0-merror:0.64403
# [122]	validation_0-merror:0.64159
# [123]	validation_0-merror:0.64194
# [124]	validation_0-merror:0.64124
# [125]	validation_0-merror:0.64263
# [126]	validation_0-merror:0.64333
# [127]	validation_0-merror:0.64263
# [128]	validation_0-merror:0.64194
# [129]	validation_0-merror:0.64298
# [130]	validation_0-merror:0.64194
# [131]	validation_0-merror:0.64194
# [132]	validation_0-merror:0.63915
# [133]	validation_0-merror:0.64437
# [134]	validation_0-merror:0.64089
# [135]	validation_0-merror:0.63985
# [136]	validation_0-merror:0.63880
# [137]	validation_0-merror:0.63741
# [138]	validation_0-merror:0.63671
# [139]	validation_0-merror:0.63776
# [140]	validation_0-merror:0.63602
# [141]	validation_0-merror:0.63532
# [142]	validation_0-merror:0.63741
# [143]	validation_0-merror:0.63532
# [144]	validation_0-merror:0.63393
# [145]	validation_0-merror:0.63427
# [146]	validation_0-merror:0.63602
# [147]	validation_0-merror:0.63427
# [148]	validation_0-merror:0.63323
# [149]	validation_0-merror:0.63497
# [150]	validation_0-merror:0.63462
# [151]	validation_0-merror:0.63532
# [152]	validation_0-merror:0.63671
# [153]	validation_0-merror:0.63671
# [154]	validation_0-merror:0.63636
# [155]	validation_0-merror:0.63497
# [156]	validation_0-merror:0.63567
# [157]	validation_0-merror:0.63393
# [158]	validation_0-merror:0.63497
# [159]	validation_0-merror:0.63253
# [160]	validation_0-merror:0.63253
# [161]	validation_0-merror:0.63044
# [162]	validation_0-merror:0.62905
# [163]	validation_0-merror:0.63009
# [164]	validation_0-merror:0.63114
# [165]	validation_0-merror:0.63184
# [166]	validation_0-merror:0.63427
# [167]	validation_0-merror:0.63358
# [168]	validation_0-merror:0.62905
# [169]	validation_0-merror:0.62975
# [170]	validation_0-merror:0.63114
# [171]	validation_0-merror:0.63114
# [172]	validation_0-merror:0.63114
# [173]	validation_0-merror:0.63044
# [174]	validation_0-merror:0.62905
# [433]	validation_0-merror:0.59700
# [434]	validation_0-merror:0.59631
# [435]	validation_0-merror:0.59666
# [436]	validation_0-merror:0.59700
# [437]	validation_0-merror:0.59561
# [438]	validation_0-merror:0.59526
# [439]	validation_0-merror:0.59596
# [440]	validation_0-merror:0.59631
# [441]	validation_0-merror:0.59561
# [442]	validation_0-merror:0.59631
# [443]	validation_0-merror:0.59526
# [444]	validation_0-merror:0.59491
# [445]	validation_0-merror:0.59631
# [446]	validation_0-merror:0.59631
# [447]	validation_0-merror:0.59666
# [448]	validation_0-merror:0.59666
# [449]	validation_0-merror:0.59596
# [450]	validation_0-merror:0.59317
# [451]	validation_0-merror:0.59317
# [452]	validation_0-merror:0.59248
# [453]	validation_0-merror:0.59178
# [454]	validation_0-merror:0.59004
# [455]	validation_0-merror:0.59178
# [456]	validation_0-merror:0.59248
# [457]	validation_0-merror:0.59178
# [458]	validation_0-merror:0.59178
# [459]	validation_0-merror:0.59178
# [460]	validation_0-merror:0.59282
# [461]	validation_0-merror:0.59317
# [462]	validation_0-merror:0.59526
# [463]	validation_0-merror:0.59317
# [464]	validation_0-merror:0.59248
# [465]	validation_0-merror:0.59178
# [466]	validation_0-merror:0.59282
# [467]	validation_0-merror:0.59178
# [468]	validation_0-merror:0.59178
# [469]	validation_0-merror:0.59422
# [470]	validation_0-merror:0.59248
# [471]	validation_0-merror:0.59213
# [472]	validation_0-merror:0.59387
# [473]	validation_0-merror:0.59317
# [474]	validation_0-merror:0.59457
# [475]	validation_0-merror:0.59317
# [476]	validation_0-merror:0.59491
# [477]	validation_0-merror:0.59422
# [478]	validation_0-merror:0.59596
# [479]	validation_0-merror:0.59596
# [480]	validation_0-merror:0.59596
# [481]	validation_0-merror:0.59596
# [482]	validation_0-merror:0.59491
# [483]	validation_0-merror:0.59457
# [484]	validation_0-merror:0.59387
# [485]	validation_0-merror:0.59422
# [486]	validation_0-merror:0.59213
# [487]	validation_0-merror:0.59422
# [488]	validation_0-merror:0.59178
# [489]	validation_0-merror:0.59248
# [490]	validation_0-merror:0.59248
# [491]	validation_0-merror:0.59282
# [492]	validation_0-merror:0.59387
# [493]	validation_0-merror:0.59317
# [494]	validation_0-merror:0.59422
# [495]	validation_0-merror:0.59352
# [496]	validation_0-merror:0.59178
# [497]	validation_0-merror:0.59143
# [498]	validation_0-merror:0.59282
# [499]	validation_0-merror:0.59282
# [500]	validation_0-merror:0.59213
# [501]	validation_0-merror:0.59213
# [502]	validation_0-merror:0.59073
# [503]	validation_0-merror:0.59073
# [504]	validation_0-merror:0.59108
# [505]	validation_0-merror:0.59143
# [506]	validation_0-merror:0.59073
# [507]	validation_0-merror:0.59213
# [508]	validation_0-merror:0.58969
# [509]	validation_0-merror:0.58934
# [510]	validation_0-merror:0.59004
# [511]	validation_0-merror:0.58934
# [512]	validation_0-merror:0.58934
# [513]	validation_0-merror:0.59039
# [514]	validation_0-merror:0.58969
# [515]	validation_0-merror:0.58934
# [516]	validation_0-merror:0.58795
# [517]	validation_0-merror:0.58760
# [518]	validation_0-merror:0.58795
# [519]	validation_0-merror:0.58934
# [520]	validation_0-merror:0.58934
# [521]	validation_0-merror:0.58830
# [522]	validation_0-merror:0.58899
# [523]	validation_0-merror:0.58795
# [524]	validation_0-merror:0.58795
# [525]	validation_0-merror:0.58969
# [526]	validation_0-merror:0.58934
# [527]	validation_0-merror:0.58865
# [528]	validation_0-merror:0.58830
# [529]	validation_0-merror:0.58795
# [530]	validation_0-merror:0.58830
# [531]	validation_0-merror:0.58865
# [532]	validation_0-merror:0.58760
# [533]	validation_0-merror:0.58586
# [534]	validation_0-merror:0.58865
# [535]	validation_0-merror:0.58760
# [536]	validation_0-merror:0.58795
# [537]	validation_0-merror:0.58865
# [538]	validation_0-merror:0.58656
# [539]	validation_0-merror:0.58621
# [540]	validation_0-merror:0.58586
# [541]	validation_0-merror:0.58621
# [542]	validation_0-merror:0.58551
# [543]	validation_0-merror:0.58656
# [544]	validation_0-merror:0.58656
# [545]	validation_0-merror:0.58725
# [546]	validation_0-merror:0.58621
# [547]	validation_0-merror:0.58516
# [548]	validation_0-merror:0.58586
# [549]	validation_0-merror:0.58586
# [550]	validation_0-merror:0.58377
# [551]	validation_0-merror:0.58481
# [552]	validation_0-merror:0.58551
# [553]	validation_0-merror:0.58412
# [554]	validation_0-merror:0.58272
# [555]	validation_0-merror:0.58481
# [556]	validation_0-merror:0.58551
# [557]	validation_0-merror:0.58586
# [558]	validation_0-merror:0.58586
# [559]	validation_0-merror:0.58621
# [560]	validation_0-merror:0.58481
# [561]	validation_0-merror:0.58516
# [562]	validation_0-merror:0.58586
# [563]	validation_0-merror:0.58586
# [564]	validation_0-merror:0.58551
# [565]	validation_0-merror:0.58516
# [566]	validation_0-merror:0.58516
# [567]	validation_0-merror:0.58621
# [568]	validation_0-merror:0.58551
# [569]	validation_0-merror:0.58586
# [570]	validation_0-merror:0.58516
# [571]	validation_0-merror:0.58481
# [572]	validation_0-merror:0.58481
# [573]	validation_0-merror:0.58586
# [574]	validation_0-merror:0.58586
# [575]	validation_0-merror:0.58481
# [576]	validation_0-merror:0.58377
# [577]	validation_0-merror:0.58238
# [578]	validation_0-merror:0.58342
# [579]	validation_0-merror:0.58377
# [580]	validation_0-merror:0.58272
# [581]	validation_0-merror:0.58377
# [582]	validation_0-merror:0.58272
# [583]	validation_0-merror:0.58307
# [584]	validation_0-merror:0.58272
# [585]	validation_0-merror:0.58377
# [586]	validation_0-merror:0.58342
# [587]	validation_0-merror:0.58342
# [588]	validation_0-merror:0.58342
# [589]	validation_0-merror:0.58272
# [590]	validation_0-merror:0.58272
# [591]	validation_0-merror:0.58238
# [592]	validation_0-merror:0.58203
# [593]	validation_0-merror:0.58272
# [594]	validation_0-merror:0.58238
# [595]	validation_0-merror:0.58168
# [596]	validation_0-merror:0.58098
# [597]	validation_0-merror:0.58168
# [598]	validation_0-merror:0.58203
# [599]	validation_0-merror:0.58098
# [600]	validation_0-merror:0.58168
# [601]	validation_0-merror:0.58063
# [602]	validation_0-merror:0.58098
# [603]	validation_0-merror:0.58133
# [604]	validation_0-merror:0.58168
# [605]	validation_0-merror:0.58238
# [606]	validation_0-merror:0.58203
# [607]	validation_0-merror:0.58203
# [608]	validation_0-merror:0.58272
# [609]	validation_0-merror:0.58307
# [610]	validation_0-merror:0.58307
# [611]	validation_0-merror:0.58272
# [612]	validation_0-merror:0.58203
# [613]	validation_0-merror:0.58238
# [614]	validation_0-merror:0.58168
# [615]	validation_0-merror:0.58168
# [616]	validation_0-merror:0.58203
# [617]	validation_0-merror:0.58168
# [618]	validation_0-merror:0.58238
# [619]	validation_0-merror:0.58272
# [620]	validation_0-merror:0.58272
# [621]	validation_0-merror:0.58272
# [622]	validation_0-merror:0.58238
# [623]	validation_0-merror:0.58307
# [624]	validation_0-merror:0.58168
# [625]	validation_0-merror:0.58342
# [626]	validation_0-merror:0.58377
# [627]	validation_0-merror:0.58272
# [628]	validation_0-merror:0.58342
# [629]	validation_0-merror:0.58203
# [630]	validation_0-merror:0.58203
# [631]	validation_0-merror:0.58133
# [632]	validation_0-merror:0.58168
# [633]	validation_0-merror:0.58203
# [634]	validation_0-merror:0.58168
# [635]	validation_0-merror:0.58029
# [636]	validation_0-merror:0.58133
# [637]	validation_0-merror:0.58203
# [638]	validation_0-merror:0.58238
# [639]	validation_0-merror:0.58272
# [640]	validation_0-merror:0.58203
# [641]	validation_0-merror:0.58168
# [642]	validation_0-merror:0.58063
# [643]	validation_0-merror:0.58203
# [644]	validation_0-merror:0.58238
# [645]	validation_0-merror:0.58272
# [646]	validation_0-merror:0.58238
# [647]	validation_0-merror:0.58203
# [648]	validation_0-merror:0.58133
# [649]	validation_0-merror:0.58168
# [650]	validation_0-merror:0.58168
# [651]	validation_0-merror:0.58238
# [652]	validation_0-merror:0.58029
# [653]	validation_0-merror:0.58063
# [654]	validation_0-merror:0.58098
# [655]	validation_0-merror:0.57994
# [656]	validation_0-merror:0.58063
# [657]	validation_0-merror:0.57959
# [658]	validation_0-merror:0.58029
# [659]	validation_0-merror:0.57994
# [660]	validation_0-merror:0.57994
# [661]	validation_0-merror:0.57889
# [662]	validation_0-merror:0.57994
# [663]	validation_0-merror:0.57959
# [664]	validation_0-merror:0.57959
# [665]	validation_0-merror:0.57924
# [666]	validation_0-merror:0.57889
# [667]	validation_0-merror:0.57889
# [668]	validation_0-merror:0.57889
# [669]	validation_0-merror:0.57785
# [670]	validation_0-merror:0.57785
# [671]	validation_0-merror:0.57750
# [672]	validation_0-merror:0.57854
# [673]	validation_0-merror:0.57854
# [674]	validation_0-merror:0.57889
# [675]	validation_0-merror:0.57854
# [676]	validation_0-merror:0.57889
# [677]	validation_0-merror:0.57750
# [678]	validation_0-merror:0.57854
# [679]	validation_0-merror:0.57854
# [680]	validation_0-merror:0.57854
# [681]	validation_0-merror:0.57820
# [682]	validation_0-merror:0.57820
# [683]	validation_0-merror:0.57924
# [684]	validation_0-merror:0.57785
# [685]	validation_0-merror:0.57750
# [686]	validation_0-merror:0.57820
# [687]	validation_0-merror:0.57820
# [688]	validation_0-merror:0.57889
# [689]	validation_0-merror:0.57994
# [690]	validation_0-merror:0.57889
# [691]	validation_0-merror:0.57854
# [692]	validation_0-merror:0.57820
# [693]	validation_0-merror:0.57889
# [694]	validation_0-merror:0.57889
# [695]	validation_0-merror:0.57924
# [696]	validation_0-merror:0.57750
# [697]	validation_0-merror:0.57854
# [698]	validation_0-merror:0.57750
# [699]	validation_0-merror:0.57820
# [700]	validation_0-merror:0.57820
# [701]	validation_0-merror:0.57645
# [702]	validation_0-merror:0.57750
# [703]	validation_0-merror:0.57680
# [704]	validation_0-merror:0.57715
# [705]	validation_0-merror:0.57750
# [706]	validation_0-merror:0.57750
# [707]	validation_0-merror:0.57750
# [708]	validation_0-merror:0.57750
# [709]	validation_0-merror:0.57750
# [710]	validation_0-merror:0.57854
# [711]	validation_0-merror:0.57680
# [712]	validation_0-merror:0.57645
# [713]	validation_0-merror:0.57611
# [714]	validation_0-merror:0.57576
# [715]	validation_0-merror:0.57611
# [716]	validation_0-merror:0.57645
# [717]	validation_0-merror:0.57541
# [718]	validation_0-merror:0.57541
# [719]	validation_0-merror:0.57611
# [720]	validation_0-merror:0.57715
# [721]	validation_0-merror:0.57680
# [722]	validation_0-merror:0.57645
# [723]	validation_0-merror:0.57680
# [724]	validation_0-merror:0.57750
# [725]	validation_0-merror:0.57680
# [726]	validation_0-merror:0.57645
# [727]	validation_0-merror:0.57680
# [728]	validation_0-merror:0.57645
# [729]	validation_0-merror:0.57576
# [730]	validation_0-merror:0.57645
# [731]	validation_0-merror:0.57680
# [732]	validation_0-merror:0.57715
# [733]	validation_0-merror:0.57680
# [734]	validation_0-merror:0.57645
# [735]	validation_0-merror:0.57750
# [736]	validation_0-merror:0.57750
# [737]	validation_0-merror:0.57680
# [738]	validation_0-merror:0.57715
# [739]	validation_0-merror:0.57645
# [740]	validation_0-merror:0.57645
# [741]	validation_0-merror:0.57715
# [742]	validation_0-merror:0.57471
# [743]	validation_0-merror:0.57506
# [744]	validation_0-merror:0.57471
# [745]	validation_0-merror:0.57506
# [746]	validation_0-merror:0.57471
# [747]	validation_0-merror:0.57436
# [748]	validation_0-merror:0.57332
# [749]	validation_0-merror:0.57402
# [750]	validation_0-merror:0.57332
# [751]	validation_0-merror:0.57541
# [752]	validation_0-merror:0.57436
# [753]	validation_0-merror:0.57402
# [754]	validation_0-merror:0.57576
# [755]	validation_0-merror:0.57541
# [756]	validation_0-merror:0.57506
# [757]	validation_0-merror:0.57402
# [758]	validation_0-merror:0.57262
# [759]	validation_0-merror:0.57227
# [760]	validation_0-merror:0.57123
# [761]	validation_0-merror:0.57123
# [762]	validation_0-merror:0.57088
# [763]	validation_0-merror:0.57262
# [764]	validation_0-merror:0.57227
# [765]	validation_0-merror:0.57123
# [766]	validation_0-merror:0.57332
# [767]	validation_0-merror:0.57262
# [768]	validation_0-merror:0.57262
# [769]	validation_0-merror:0.57262
# [770]	validation_0-merror:0.57262
# [771]	validation_0-merror:0.57053
# [772]	validation_0-merror:0.57193
# [773]	validation_0-merror:0.57297
# [774]	validation_0-merror:0.57297
# [775]	validation_0-merror:0.57262
# [776]	validation_0-merror:0.57332
# [777]	validation_0-merror:0.57332
# [778]	validation_0-merror:0.57297
# [779]	validation_0-merror:0.57262
# [780]	validation_0-merror:0.57332
# [781]	validation_0-merror:0.57227
# [782]	validation_0-merror:0.57332
# [783]	validation_0-merror:0.57158
# [784]	validation_0-merror:0.57297
# [785]	validation_0-merror:0.57332
# [786]	validation_0-merror:0.57227
# [787]	validation_0-merror:0.57297
# [788]	validation_0-merror:0.57332
# [789]	validation_0-merror:0.57262
# [790]	validation_0-merror:0.57297
# [791]	validation_0-merror:0.57193
# [792]	validation_0-merror:0.57088
# [793]	validation_0-merror:0.57158
# [794]	validation_0-merror:0.57158
# [795]	validation_0-merror:0.57123
# [796]	validation_0-merror:0.57088
# [797]	validation_0-merror:0.57053
# [798]	validation_0-merror:0.57018
# [799]	validation_0-merror:0.56879
# [800]	validation_0-merror:0.57018
# [801]	validation_0-merror:0.57193
# [802]	validation_0-merror:0.57123
# [803]	validation_0-merror:0.57053
# [804]	validation_0-merror:0.57053
# [805]	validation_0-merror:0.57018
# [806]	validation_0-merror:0.57053
# [807]	validation_0-merror:0.57018
# [808]	validation_0-merror:0.56984
# [809]	validation_0-merror:0.56984
# [810]	validation_0-merror:0.57088
# [811]	validation_0-merror:0.57018
# [812]	validation_0-merror:0.57018
# [813]	validation_0-merror:0.56984
# [814]	validation_0-merror:0.56949
# [815]	validation_0-merror:0.56949
# [816]	validation_0-merror:0.56984
# [817]	validation_0-merror:0.57088
# [818]	validation_0-merror:0.57123
# [819]	validation_0-merror:0.57123
# [820]	validation_0-merror:0.57088
# [821]	validation_0-merror:0.57088
# [822]	validation_0-merror:0.57123
# [823]	validation_0-merror:0.57193
# [824]	validation_0-merror:0.57227
# [825]	validation_0-merror:0.57227
# [826]	validation_0-merror:0.57158
# [827]	validation_0-merror:0.57053
# [828]	validation_0-merror:0.57123
# [829]	validation_0-merror:0.57088
# [830]	validation_0-merror:0.57123
# [831]	validation_0-merror:0.56984
# [832]	validation_0-merror:0.57053
# [833]	validation_0-merror:0.57018
# [834]	validation_0-merror:0.57053
# [835]	validation_0-merror:0.57088
# [836]	validation_0-merror:0.57053
# [837]	validation_0-merror:0.57158
# [838]	validation_0-merror:0.57193
# [839]	validation_0-merror:0.57123
# [840]	validation_0-merror:0.57158
# [841]	validation_0-merror:0.57158
# [842]	validation_0-merror:0.57018
# [843]	validation_0-merror:0.57088
# [844]	validation_0-merror:0.57158
# [845]	validation_0-merror:0.57158
# [846]	validation_0-merror:0.57088
# [847]	validation_0-merror:0.57123
# [848]	validation_0-merror:0.57123
# [849]	validation_0-merror:0.56984
# [850]	validation_0-merror:0.57018
# [851]	validation_0-merror:0.56949
# [852]	validation_0-merror:0.57088
# [853]	validation_0-merror:0.57018
# [854]	validation_0-merror:0.56984
# [855]	validation_0-merror:0.57053
# [856]	validation_0-merror:0.56984
# [857]	validation_0-merror:0.56879
# [858]	validation_0-merror:0.56984
# [859]	validation_0-merror:0.57018
# [860]	validation_0-merror:0.56949
# [861]	validation_0-merror:0.57123
# [862]	validation_0-merror:0.56949
# [863]	validation_0-merror:0.57018
# [864]	validation_0-merror:0.57088
# [865]	validation_0-merror:0.57088
# [866]	validation_0-merror:0.57053
# [867]	validation_0-merror:0.56984
# [868]	validation_0-merror:0.56984
# [869]	validation_0-merror:0.57018
# [870]	validation_0-merror:0.57053
# [871]	validation_0-merror:0.57088
# [872]	validation_0-merror:0.57088
# [873]	validation_0-merror:0.57158
# [874]	validation_0-merror:0.57123
# [875]	validation_0-merror:0.56949
# [876]	validation_0-merror:0.57018
# [877]	validation_0-merror:0.56984
# [878]	validation_0-merror:0.56879
# [879]	validation_0-merror:0.56844
# [880]	validation_0-merror:0.56914
# [881]	validation_0-merror:0.56879
# [882]	validation_0-merror:0.56844
# [883]	validation_0-merror:0.56844
# [884]	validation_0-merror:0.56844
# [885]	validation_0-merror:0.56914
# [886]	validation_0-merror:0.56844
# [887]	validation_0-merror:0.56879
# [888]	validation_0-merror:0.56879
# [889]	validation_0-merror:0.56844
# [890]	validation_0-merror:0.56879
# [891]	validation_0-merror:0.56879
# [892]	validation_0-merror:0.56949
# [893]	validation_0-merror:0.56914
# [894]	validation_0-merror:0.56914
# [895]	validation_0-merror:0.56914
# [896]	validation_0-merror:0.56879
# [897]	validation_0-merror:0.56879
# [898]	validation_0-merror:0.56914
# [899]	validation_0-merror:0.56914
# [900]	validation_0-merror:0.56984
# [901]	validation_0-merror:0.57018
# [902]	validation_0-merror:0.56879
# [903]	validation_0-merror:0.56914
# [904]	validation_0-merror:0.56984
# [905]	validation_0-merror:0.56879
# [906]	validation_0-merror:0.56844
# [907]	validation_0-merror:0.57018
# [908]	validation_0-merror:0.57053
# [909]	validation_0-merror:0.56914
# [910]	validation_0-merror:0.56844
# [911]	validation_0-merror:0.56844
# [912]	validation_0-merror:0.56775
# [913]	validation_0-merror:0.56809
# [914]	validation_0-merror:0.56740
# [915]	validation_0-merror:0.56775
# [916]	validation_0-merror:0.56705
# [917]	validation_0-merror:0.56635
# [918]	validation_0-merror:0.56670
# [919]	validation_0-merror:0.56566
# [920]	validation_0-merror:0.56705
# [921]	validation_0-merror:0.56705
# [922]	validation_0-merror:0.56705
# [923]	validation_0-merror:0.56705
# [924]	validation_0-merror:0.56740
# [925]	validation_0-merror:0.56740
# [926]	validation_0-merror:0.56670
# [927]	validation_0-merror:0.56496
# [928]	validation_0-merror:0.56600
# [929]	validation_0-merror:0.56635
# [930]	validation_0-merror:0.56670
# [931]	validation_0-merror:0.56670
# [932]	validation_0-merror:0.56670
# [933]	validation_0-merror:0.56635
# [934]	validation_0-merror:0.56705
# [935]	validation_0-merror:0.56635
# [936]	validation_0-merror:0.56635
# [937]	validation_0-merror:0.56670
# [938]	validation_0-merror:0.56705
# [939]	validation_0-merror:0.56566
# [940]	validation_0-merror:0.56670
# [941]	validation_0-merror:0.56705
# [942]	validation_0-merror:0.56635
# [943]	validation_0-merror:0.56670
# [944]	validation_0-merror:0.56740
# [945]	validation_0-merror:0.56740
# [946]	validation_0-merror:0.56775
# [947]	validation_0-merror:0.56844
# [948]	validation_0-merror:0.56740
# [949]	validation_0-merror:0.56600
# [950]	validation_0-merror:0.56635
# [951]	validation_0-merror:0.56600
# [952]	validation_0-merror:0.56740
# [953]	validation_0-merror:0.56705
# [954]	validation_0-merror:0.56670
# [955]	validation_0-merror:0.56600
# [956]	validation_0-merror:0.56600
# [957]	validation_0-merror:0.56566
# [958]	validation_0-merror:0.56635
# [959]	validation_0-merror:0.56600
# [960]	validation_0-merror:0.56531
# [961]	validation_0-merror:0.56635
# [962]	validation_0-merror:0.56600
# [963]	validation_0-merror:0.56566
# [964]	validation_0-merror:0.56566
# [965]	validation_0-merror:0.56635
# [966]	validation_0-merror:0.56531
# [967]	validation_0-merror:0.56600
# [968]	validation_0-merror:0.56635
# [969]	validation_0-merror:0.56566
# [970]	validation_0-merror:0.56531
# [971]	validation_0-merror:0.56600
# [972]	validation_0-merror:0.56635
# [973]	validation_0-merror:0.56531
# [974]	validation_0-merror:0.56531
# [975]	validation_0-merror:0.56461
# [976]	validation_0-merror:0.56426
# [977]	validation_0-merror:0.56531
# [978]	validation_0-merror:0.56566
# [979]	validation_0-merror:0.56635
# [980]	validation_0-merror:0.56600
# [981]	validation_0-merror:0.56600
# [982]	validation_0-merror:0.56531
# [983]	validation_0-merror:0.56531
# [984]	validation_0-merror:0.56461
# [985]	validation_0-merror:0.56566
# [986]	validation_0-merror:0.56566
# [987]	validation_0-merror:0.56496
# [988]	validation_0-merror:0.56496
# [989]	validation_0-merror:0.56566
# [990]	validation_0-merror:0.56496
# [991]	validation_0-merror:0.56670
# [992]	validation_0-merror:0.56670
# [993]	validation_0-merror:0.56635
# [994]	validation_0-merror:0.56670
# [995]	validation_0-merror:0.56670
# [996]	validation_0-merror:0.56740
# [997]	validation_0-merror:0.56705
# [998]	validation_0-merror:0.56705
# [999]	validation_0-merror:0.56740
# [1000]	validation_0-merror:0.56670
# [1001]	validation_0-merror:0.56670
# [1002]	validation_0-merror:0.56705
# [1003]	validation_0-merror:0.56670
# [1004]	validation_0-merror:0.56670
# [1005]	validation_0-merror:0.56635
# [1006]	validation_0-merror:0.56670
# [1007]	validation_0-merror:0.56705
# [1008]	validation_0-merror:0.56670
# [1009]	validation_0-merror:0.56705
# [1010]	validation_0-merror:0.56670
# [1011]	validation_0-merror:0.56705
# [1012]	validation_0-merror:0.56705
# [1013]	validation_0-merror:0.56775
# [1014]	validation_0-merror:0.56705
# [1015]	validation_0-merror:0.56670
# [1016]	validation_0-merror:0.56670
# [1017]	validation_0-merror:0.56705
# [1018]	validation_0-merror:0.56705
# [1019]	validation_0-merror:0.56740
# [1020]	validation_0-merror:0.56775
# [1021]	validation_0-merror:0.56809
# [1022]	validation_0-merror:0.56775
# [1023]	validation_0-merror:0.56844
# [1024]	validation_0-merror:0.56740
# [1025]	validation_0-merror:0.56705
# [1026]	validation_0-merror:0.56600
# [1027]	validation_0-merror:0.56600
# [1028]	validation_0-merror:0.56566
# [1029]	validation_0-merror:0.56566
# [1030]	validation_0-merror:0.56566
# [1031]	validation_0-merror:0.56566
# [2787]	validation_0-merror:0.54650
# [2788]	validation_0-merror:0.54650
# [2789]	validation_0-merror:0.54650
# [2790]	validation_0-merror:0.54650
# [2791]	validation_0-merror:0.54685
# [2792]	validation_0-merror:0.54650
# [2793]	validation_0-merror:0.54685
# [2794]	validation_0-merror:0.54720
# [2795]	validation_0-merror:0.54720
# [2796]	validation_0-merror:0.54754
# [2797]	validation_0-merror:0.54824
# [2798]	validation_0-merror:0.54685
# [2799]	validation_0-merror:0.54720
# [2800]	validation_0-merror:0.54685
# [2801]	validation_0-merror:0.54789
# [2802]	validation_0-merror:0.54650
# [2803]	validation_0-merror:0.54789
# [2804]	validation_0-merror:0.54720
# [2805]	validation_0-merror:0.54789
# [2806]	validation_0-merror:0.54754
# [2807]	validation_0-merror:0.54754
# [2808]	validation_0-merror:0.54824
# [2809]	validation_0-merror:0.54859
# [2810]	validation_0-merror:0.54929
# [2811]	validation_0-merror:0.54894
# [2812]	validation_0-merror:0.54859
# [2813]	validation_0-merror:0.54894
# [2814]	validation_0-merror:0.54824
# [2815]	validation_0-merror:0.54720
# [2816]	validation_0-merror:0.54789
# [2817]	validation_0-merror:0.54754
# [2818]	validation_0-merror:0.54720
# [2819]	validation_0-merror:0.54789
# [2820]	validation_0-merror:0.54789
# [2821]	validation_0-merror:0.54824
# [2822]	validation_0-merror:0.54789
# [2823]	validation_0-merror:0.54894
# [2824]	validation_0-merror:0.54894
# [2825]	validation_0-merror:0.54824
# [2826]	validation_0-merror:0.54824
# [2827]	validation_0-merror:0.54859
# [2828]	validation_0-merror:0.54789
# [2829]	validation_0-merror:0.54789
# [2830]	validation_0-merror:0.54824
# [2831]	validation_0-merror:0.54824
# [2832]	validation_0-merror:0.54824
# [2833]	validation_0-merror:0.54824
# [2834]	validation_0-merror:0.54789
# [2835]	validation_0-merror:0.54824
# [2836]	validation_0-merror:0.54824
# [2837]	validation_0-merror:0.54859
# [2838]	validation_0-merror:0.54894
# [2839]	validation_0-merror:0.54894
# [2840]	validation_0-merror:0.54929
# [2841]	validation_0-merror:0.54963
# [2842]	validation_0-merror:0.54963
# [2843]	validation_0-merror:0.54998
# [2844]	validation_0-merror:0.54998
# [2845]	validation_0-merror:0.55033
# [2846]	validation_0-merror:0.54963
# [2847]	validation_0-merror:0.54998
# [2848]	validation_0-merror:0.54963
# [2849]	validation_0-merror:0.54894
# [2850]	validation_0-merror:0.54894
# [2851]	validation_0-merror:0.54894
# [2852]	validation_0-merror:0.54963
# [2853]	validation_0-merror:0.54963
# [2854]	validation_0-merror:0.55068
# [2855]	validation_0-merror:0.54998
# [2856]	validation_0-merror:0.55033
# [2857]	validation_0-merror:0.54998
# [2858]	validation_0-merror:0.55033
# [2859]	validation_0-merror:0.55068
# [2860]	validation_0-merror:0.55103
# [2861]	validation_0-merror:0.55207
# [2862]	validation_0-merror:0.55207
# [2863]	validation_0-merror:0.55207
# [2864]	validation_0-merror:0.55242
# [2865]	validation_0-merror:0.55242
# [2866]	validation_0-merror:0.55277
# [2867]	validation_0-merror:0.55277
# [2868]	validation_0-merror:0.55207
# [2869]	validation_0-merror:0.55207
# [2870]	validation_0-merror:0.55207
# [2871]	validation_0-merror:0.55172
# [2872]	validation_0-merror:0.55172
# [2873]	validation_0-merror:0.55207
# [2874]	validation_0-merror:0.55277
# [2875]	validation_0-merror:0.55242
# [2876]	validation_0-merror:0.55207
# [2877]	validation_0-merror:0.55207
# [2878]	validation_0-merror:0.55138
# [2879]	validation_0-merror:0.55138
# [2880]	validation_0-merror:0.55103
# [2881]	validation_0-merror:0.55138
# [2882]	validation_0-merror:0.55103
# [2883]	validation_0-merror:0.55138
# [2884]	validation_0-merror:0.55103
# [2885]	validation_0-merror:0.55068
# [2886]	validation_0-merror:0.55068
# [2887]	validation_0-merror:0.54998
# [2888]	validation_0-merror:0.54998
# [2889]	validation_0-merror:0.54963
# [2890]	validation_0-merror:0.55033
# [2891]	validation_0-merror:0.54998
# [2892]	validation_0-merror:0.55068
# [2893]	validation_0-merror:0.54998
# [2894]	validation_0-merror:0.54963
# [2895]	validation_0-merror:0.54929
# [2896]	validation_0-merror:0.54998
# [2897]	validation_0-merror:0.54998
# [2898]	validation_0-merror:0.54963
# [2899]	validation_0-merror:0.54963
# [2900]	validation_0-merror:0.54963
# [2901]	validation_0-merror:0.54894
# [2902]	validation_0-merror:0.54859
# [2903]	validation_0-merror:0.54894
# [2904]	validation_0-merror:0.54929
# [2905]	validation_0-merror:0.54859
# [2906]	validation_0-merror:0.54859
# [2907]	validation_0-merror:0.54859
# [2908]	validation_0-merror:0.54894
# [2909]	validation_0-merror:0.54754
# [2910]	validation_0-merror:0.54754
# [2911]	validation_0-merror:0.54650
# [2912]	validation_0-merror:0.54720
# [2913]	validation_0-merror:0.54685
# [2914]	validation_0-merror:0.54720
# [2915]	validation_0-merror:0.54720
# [2916]	validation_0-merror:0.54720
# [2917]	validation_0-merror:0.54650
# [2918]	validation_0-merror:0.54650
# [2919]	validation_0-merror:0.54685
# [2920]	validation_0-merror:0.54720
# [2921]	validation_0-merror:0.54789
# [2922]	validation_0-merror:0.54824
# [2923]	validation_0-merror:0.54824
# [2924]	validation_0-merror:0.54754
# [2925]	validation_0-merror:0.54789
# [2926]	validation_0-merror:0.54720
# [2927]	validation_0-merror:0.54754
# [2928]	validation_0-merror:0.54789
# [2929]	validation_0-merror:0.54824
# [2930]	validation_0-merror:0.54824
# [2931]	validation_0-merror:0.54824
# [2932]	validation_0-merror:0.54859
# [2933]	validation_0-merror:0.54894
# [2934]	validation_0-merror:0.54894
# [2935]	validation_0-merror:0.54998
# [2936]	validation_0-merror:0.55033
# [2937]	validation_0-merror:0.55033
# [2938]	validation_0-merror:0.54963
# [2939]	validation_0-merror:0.55068
# [2940]	validation_0-merror:0.55033
# [2941]	validation_0-merror:0.54963
# [2942]	validation_0-merror:0.54824
# [2943]	validation_0-merror:0.54894
# [2944]	validation_0-merror:0.54963
# [2945]	validation_0-merror:0.54929
# [2946]	validation_0-merror:0.54894
# [2947]	validation_0-merror:0.54789
# [2948]	validation_0-merror:0.54859
# [2949]	validation_0-merror:0.54824
# [2950]	validation_0-merror:0.54754
# [2951]	validation_0-merror:0.54685
# [2952]	validation_0-merror:0.54720
# [2953]	validation_0-merror:0.54754
# [2954]	validation_0-merror:0.54685
# [2955]	validation_0-merror:0.54754
# [2956]	validation_0-merror:0.54754
# [2957]	validation_0-merror:0.54824
# [2958]	validation_0-merror:0.54859
# [2959]	validation_0-merror:0.54929
# [2960]	validation_0-merror:0.54963
# [2961]	validation_0-merror:0.54824
# [2962]	validation_0-merror:0.54859
# [2963]	validation_0-merror:0.54789
# [2964]	validation_0-merror:0.54824
# [2965]	validation_0-merror:0.54824
# [2966]	validation_0-merror:0.54789
# [2967]	validation_0-merror:0.54789
# [2968]	validation_0-merror:0.54894
# [2969]	validation_0-merror:0.54998
# [2970]	validation_0-merror:0.54998
# [2971]	validation_0-merror:0.55033
# [2972]	validation_0-merror:0.54963
# [2973]	validation_0-merror:0.55033
# [2974]	validation_0-merror:0.54963
# [2975]	validation_0-merror:0.54998
# [2976]	validation_0-merror:0.54963
# [2977]	validation_0-merror:0.54894
# [2978]	validation_0-merror:0.54894
# [2979]	validation_0-merror:0.54824
# [2980]	validation_0-merror:0.54859
# [2981]	validation_0-merror:0.54859
# [2982]	validation_0-merror:0.54859
# [2983]	validation_0-merror:0.54894
# [2984]	validation_0-merror:0.54859
# [2985]	validation_0-merror:0.54754
# [2986]	validation_0-merror:0.54789
# [2987]	validation_0-merror:0.54789
# [2988]	validation_0-merror:0.54789
# [2989]	validation_0-merror:0.54789
# [2990]	validation_0-merror:0.54789
# [2991]	validation_0-merror:0.54824
# [2992]	validation_0-merror:0.54824
# [2993]	validation_0-merror:0.54824
# [2994]	validation_0-merror:0.54824
# [2995]	validation_0-merror:0.54789
# [2996]	validation_0-merror:0.54824
# [2997]	validation_0-merror:0.54754
# [2998]	validation_0-merror:0.54720
# [2999]	validation_0-merror:0.54754
# [3000]	validation_0-merror:0.54824
# [3001]	validation_0-merror:0.54894
# [3002]	validation_0-merror:0.54929
# [3003]	validation_0-merror:0.54859
# [3004]	validation_0-merror:0.54859
# [3005]	validation_0-merror:0.54929
# [3006]	validation_0-merror:0.54789
# [3007]	validation_0-merror:0.54859
# [3008]	validation_0-merror:0.54929
# [3009]	validation_0-merror:0.55033
# [3010]	validation_0-merror:0.54998
# [3011]	validation_0-merror:0.55033
# [3012]	validation_0-merror:0.55033
# [3013]	validation_0-merror:0.54998
# [3014]	validation_0-merror:0.55033
# [3015]	validation_0-merror:0.54998
# [3016]	validation_0-merror:0.55068
# [3017]	validation_0-merror:0.55033
# [3018]	validation_0-merror:0.55103
# [3019]	validation_0-merror:0.55033
# [3020]	validation_0-merror:0.55033
# [3021]	validation_0-merror:0.55103
# [3022]	validation_0-merror:0.55103
# [3023]	validation_0-merror:0.55033
# [3024]	validation_0-merror:0.54998
# [3025]	validation_0-merror:0.54998
# [3026]	validation_0-merror:0.55103
# [3027]	validation_0-merror:0.54998
# [3028]	validation_0-merror:0.55068
# [3029]	validation_0-merror:0.55033
# [3030]	validation_0-merror:0.55033
# [3031]	validation_0-merror:0.55033
# [3032]	validation_0-merror:0.54963
# [3033]	validation_0-merror:0.55033
# [3034]	validation_0-merror:0.54963
# [3035]	validation_0-merror:0.54824
# [3036]	validation_0-merror:0.54824
# [3037]	validation_0-merror:0.54824
# [3038]	validation_0-merror:0.54929
# [3039]	validation_0-merror:0.54859
# [3040]	validation_0-merror:0.54859
# [3041]	validation_0-merror:0.54859
# [3042]	validation_0-merror:0.54720
# [3043]	validation_0-merror:0.54824
# [3044]	validation_0-merror:0.54789
# [3045]	validation_0-merror:0.54789
# [3046]	validation_0-merror:0.54754
# [3047]	validation_0-merror:0.54859
# [3048]	validation_0-merror:0.54754
# [3049]	validation_0-merror:0.54789
# [3050]	validation_0-merror:0.54650
# [3051]	validation_0-merror:0.54685
# [3052]	validation_0-merror:0.54720
# [3053]	validation_0-merror:0.54789
# [3054]	validation_0-merror:0.54720
# [3055]	validation_0-merror:0.54754
# [3056]	validation_0-merror:0.54754
# [3057]	validation_0-merror:0.54824
# [3058]	validation_0-merror:0.54824
# [3059]	validation_0-merror:0.54824
# [3060]	validation_0-merror:0.54720
# [3061]	validation_0-merror:0.54720
# [3062]	validation_0-merror:0.54754
# [3063]	validation_0-merror:0.54720
# [3064]	validation_0-merror:0.54650
# [3065]	validation_0-merror:0.54545
# [3066]	validation_0-merror:0.54615
# [3067]	validation_0-merror:0.54650
# [3068]	validation_0-merror:0.54720
# [3069]	validation_0-merror:0.54685
# [3070]	validation_0-merror:0.54615
# [3071]	validation_0-merror:0.54615
# [3072]	validation_0-merror:0.54580
# [3073]	validation_0-merror:0.54580
# [3074]	validation_0-merror:0.54511
# [3075]	validation_0-merror:0.54580
# [3076]	validation_0-merror:0.54615
# [3077]	validation_0-merror:0.54650
# [3078]	validation_0-merror:0.54650
# [3079]	validation_0-merror:0.54650
# [3080]	validation_0-merror:0.54685
# [3081]	validation_0-merror:0.54720
# [3082]	validation_0-merror:0.54685
# [3083]	validation_0-merror:0.54580
# [3084]	validation_0-merror:0.54580
# [3085]	validation_0-merror:0.54615
# [3086]	validation_0-merror:0.54615
# [3087]	validation_0-merror:0.54720
# [3088]	validation_0-merror:0.54720
# [3089]	validation_0-merror:0.54685
# [3090]	validation_0-merror:0.54859
# [3091]	validation_0-merror:0.54789
# [3092]	validation_0-merror:0.54824
# [3093]	validation_0-merror:0.54685
# [3094]	validation_0-merror:0.54685
# [3095]	validation_0-merror:0.54754
# [3096]	validation_0-merror:0.54685
# [3097]	validation_0-merror:0.54720
# [3098]	validation_0-merror:0.54789
# [3099]	validation_0-merror:0.54720
# [3100]	validation_0-merror:0.54754
# [3101]	validation_0-merror:0.54720
# [3102]	validation_0-merror:0.54720
# [3103]	validation_0-merror:0.54789
# [3104]	validation_0-merror:0.54754
# [3105]	validation_0-merror:0.54859
# [3106]	validation_0-merror:0.54789
# [3107]	validation_0-merror:0.54720
# [3108]	validation_0-merror:0.54754
# [3109]	validation_0-merror:0.54685
# [3110]	validation_0-merror:0.54720
# [3111]	validation_0-merror:0.54754
# [3112]	validation_0-merror:0.54720
# [3113]	validation_0-merror:0.54720
# [3114]	validation_0-merror:0.54650
# [3115]	validation_0-merror:0.54685
# [3116]	validation_0-merror:0.54685
# [3117]	validation_0-merror:0.54720
# [3118]	validation_0-merror:0.54824
# [3119]	validation_0-merror:0.54754
# [3120]	validation_0-merror:0.54754
# [3121]	validation_0-merror:0.54685
# [3122]	validation_0-merror:0.54754
# [3123]	validation_0-merror:0.54685
# [3124]	validation_0-merror:0.54720
# [3125]	validation_0-merror:0.54754
# [3126]	validation_0-merror:0.54789
# [3127]	validation_0-merror:0.54824
# [3128]	validation_0-merror:0.54929
# [3129]	validation_0-merror:0.54859
# [3130]	validation_0-merror:0.54824
# [3131]	validation_0-merror:0.54685
# [3132]	validation_0-merror:0.54685
# [3133]	validation_0-merror:0.54720
# [3134]	validation_0-merror:0.54720
# [3135]	validation_0-merror:0.54685
# [3136]	validation_0-merror:0.54789
# [3137]	validation_0-merror:0.54685
# [3138]	validation_0-merror:0.54720
# [3139]	validation_0-merror:0.54685
# [3140]	validation_0-merror:0.54754
# [3141]	validation_0-merror:0.54754
# [3142]	validation_0-merror:0.54754
# [3143]	validation_0-merror:0.54754
# [3144]	validation_0-merror:0.54789
# [3145]	validation_0-merror:0.54720
# [3146]	validation_0-merror:0.54650
# [3147]	validation_0-merror:0.54650
# [3148]	validation_0-merror:0.54650
# [3149]	validation_0-merror:0.54720
# [3150]	validation_0-merror:0.54720
# [3151]	validation_0-merror:0.54754
# [3152]	validation_0-merror:0.54650
# [3153]	validation_0-merror:0.54580
# [3154]	validation_0-merror:0.54545
# [3155]	validation_0-merror:0.54650
# [3156]	validation_0-merror:0.54615
# [3157]	validation_0-merror:0.54545
# [3158]	validation_0-merror:0.54545
# [3159]	validation_0-merror:0.54476
# [3160]	validation_0-merror:0.54511
# [3161]	validation_0-merror:0.54511
# [3162]	validation_0-merror:0.54476
# [3163]	validation_0-merror:0.54545
# [3164]	validation_0-merror:0.54511
# [3165]	validation_0-merror:0.54511
# [3166]	validation_0-merror:0.54476
# [3167]	validation_0-merror:0.54441
# [3168]	validation_0-merror:0.54511
# [3169]	validation_0-merror:0.54511
# [3170]	validation_0-merror:0.54650
# [3171]	validation_0-merror:0.54720
# [3172]	validation_0-merror:0.54615
# [3173]	validation_0-merror:0.54650
# [3174]	validation_0-merror:0.54650
# [3175]	validation_0-merror:0.54580
# [3176]	validation_0-merror:0.54650
# [3177]	validation_0-merror:0.54685
# [3178]	validation_0-merror:0.54720
# [3179]	validation_0-merror:0.54754
# [3180]	validation_0-merror:0.54685
# [3181]	validation_0-merror:0.54685
# [3182]	validation_0-merror:0.54789
# [3183]	validation_0-merror:0.54720
# [3184]	validation_0-merror:0.54685
# [3185]	validation_0-merror:0.54685
# [3186]	validation_0-merror:0.54754
# [3187]	validation_0-merror:0.54685
# [3188]	validation_0-merror:0.54650
# [3189]	validation_0-merror:0.54615
# [3190]	validation_0-merror:0.54650
# [3191]	validation_0-merror:0.54615
# [3192]	validation_0-merror:0.54615
# [3193]	validation_0-merror:0.54650
# [3194]	validation_0-merror:0.54789
# [3195]	validation_0-merror:0.54824
# [3196]	validation_0-merror:0.54754
# [3197]	validation_0-merror:0.54720
# [3198]	validation_0-merror:0.54789
# [3199]	validation_0-merror:0.54824
# [3200]	validation_0-merror:0.54859
# [3201]	validation_0-merror:0.54894
# [3202]	validation_0-merror:0.54998
# [3203]	validation_0-merror:0.54894
# [3204]	validation_0-merror:0.54929
# [3205]	validation_0-merror:0.54929
# [3206]	validation_0-merror:0.54963
# [3207]	validation_0-merror:0.54998
# Runtime: 21.507132792472838 mins

# %%
# train accuracy
print(accuracy_score(train_Class_encoded, train_Class_pred))
        
# classification_report
print(classification_report(train_Class_encoded, train_Class_pred))
# Out:
# 0.9442683479048382
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94      3995
#            1       1.00      0.92      0.95       436
#            2       0.97      0.92      0.94      4097
#            3       0.91      0.98      0.95      7215
#            4       0.94      0.94      0.94      4965
#            5       0.94      0.93      0.93      4830
#            6       0.98      0.95      0.96      3171
#
#     accuracy                           0.94     28709
#    macro avg       0.96      0.94      0.95     28709
# weighted avg       0.95      0.94      0.94     28709

# %%
# train accuracy
print(accuracy_score(test_Class_encoded, test_Class_pred))
        
# classification_report
print(classification_report(test_Class_encoded, test_Class_pred))
# Out:
# 0.4667038172192811
#               precision    recall  f1-score   support
#
#            0       0.43      0.23      0.30       958
#            1       1.00      0.27      0.43       111
#            2       0.48      0.23      0.31      1024
#            3       0.47      0.84      0.60      1774
#            4       0.41      0.43      0.42      1233
#            5       0.36      0.32      0.34      1247
#            6       0.82      0.53      0.64       831
#
#     accuracy                           0.47      7178
#    macro avg       0.57      0.41      0.43      7178
# weighted avg       0.48      0.47      0.44      7178

# %% [markdown]
# ### Method 3: Gaber filter & PCA, stack with HOG & PCA

# %%
# define differnet functions to apply gabor filter and HOG features extraction
def Gabor(image):
    kernel = np.real(gabor_kernel(
                    frequency=2, 
                    theta=2/4*np.pi,
                    sigma_x=1, sigma_y=1))

    filtered_image = cv2.filter2D(image, cv2.CV_8UC3, kernel)
    return filtered_image

def HOG(image):
    HOG_features = hog(image, 
                        orientations=6, 
                        pixels_per_cell=(8, 8),
                        cells_per_block=(4, 4), 
                        visualize=False)
                        # channel_axis=-1
    return HOG_features

# %%
# Apply the Gabor and HOG respectively to each image
train_images_Gabor = []
for i in range(train_images.shape[0]):
    image = train_images[i]
    filtered_image = Gabor(image)
    train_images_Gabor.append(filtered_image)
train_images_Gabor = np.array(train_images_Gabor)
train_images_Gabor = train_images_Gabor.reshape((train_images_Gabor.shape[0],-1))
print(train_images_Gabor.shape)  # Print the shape of the resulting feature array


test_images_Gabor = []
for i in range(test_images.shape[0]):
    image = test_images[i]
    filtered_image = Gabor(image)
    test_images_Gabor.append(filtered_image)
test_images_Gabor = np.array(test_images_Gabor)
test_images_Gabor = test_images_Gabor.reshape((test_images_Gabor.shape[0],-1))
print(test_images_Gabor.shape)  # Print the shape of the resulting feature array


train_images_HOG = []
for i in range(train_images.shape[0]):
    image = train_images[i]
    features = HOG(image)
    train_images_HOG.append(features)
train_images_HOG = np.array(train_images_HOG)
print(train_images_HOG.shape)  # Print the shape of the resulting feature array

test_images_HOG = []
for i in range(test_images.shape[0]):
    image = test_images[i]
    features = HOG(image)
    test_images_HOG.append(features)
test_images_HOG = np.array(test_images_HOG)
print(test_images_HOG.shape)  # Print the shape of the resulting feature array
# Out:
# (28709, 2304)
# (7178, 2304)
# (28709, 864)
# (7178, 864)

# %%
# Apply PCA to Gabor data
from sklearn.decomposition import PCA
# Standardize the data and PCA
scaler = StandardScaler()
scaler.fit(train_images_Gabor)
train_images_Gabor_scaled = scaler.transform(train_images_Gabor)
test_images_Gabor_scaled = scaler.transform(test_images_Gabor)

pca = PCA()  # Keep all components initially
principalComponents = pca.fit_transform(train_images_Gabor_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

# Find the index where cumulative variance exceeds 0.80
n_components = len(cumulative_variance_ratio[cumulative_variance_ratio <= 0.9]) + 1 

print(f"Number of components to explain 90% variance: {n_components}")

# do the PCA transformation to the Gabor data
pca = PCA(n_components=n_components)
train_images_Gabor_pca = pca.fit_transform(train_images_Gabor_scaled)
test_images_Gabor_pca = pca.transform(test_images_Gabor_scaled)
print(train_images_Gabor_pca.shape)
print(test_images_Gabor_pca.shape)
# Out:
# Number of components to explain 90% variance: 37
# (28709, 37)
# (7178, 37)

# %%
# Apply PCA to HOG features
# Standardize the data and PCA
scaler = StandardScaler()
scaler.fit(train_images_HOG)
train_images_HOG_scaled = scaler.transform(train_images_HOG)
test_images_HOG_scaled = scaler.transform(test_images_HOG)

pca = PCA()  # Keep all components initially
principalComponents = pca.fit_transform(train_images_HOG_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()

# Find the index where cumulative variance exceeds 0.80
n_components = len(cumulative_variance_ratio[cumulative_variance_ratio <= 0.9]) + 1 

print(f"Number of components to explain 90% variance: {n_components}")

# do the PCA transformation to the Gabor data
pca = PCA(n_components=n_components)
train_images_HOG_pca = pca.fit_transform(train_images_HOG_scaled)
test_images_HOG_pca = pca.transform(test_images_HOG_scaled)
print(train_images_HOG_pca.shape)
print(test_images_HOG_pca.shape)
# Out:
# Number of components to explain 90% variance: 131
# (28709, 131)
# (7178, 131)

# %%
# Combine Gabar and HOG data
train_images_pca = np.concatenate((train_images_Gabor_pca, train_images_HOG_pca), axis=1)
test_images_pca = np.concatenate((test_images_Gabor_pca, test_images_HOG_pca), axis=1)
print(train_images_pca.shape)
print(test_images_pca.shape)
# Out:
# (28709, 168)
# (7178, 168)

# %%
# Assuming you have your data as X and y

def auto_xgboost(
    X,
    y,
    n_estimators=200,
    random_state=2024,
    cv=10
    ):
    # 1. Parameter grid
    param_grid = {
        'max_depth': [5, 10, 20, 30],
        'learning_rate': [0.01, 0.05, 0.1],
        'colsample_bytree': [0.1, 0.3, 0.5]
        # 'min_child_weight': [1, 2, 5, 10, 20]
        # 'gamma': [0, 0.1],
        # 'subsample': [0.8, 1.0]
    }
    # 2. Create base model
    xgb_model = XGBClassifier(
        objective='multi:softmax',
        n_estimators= n_estimators,
        subsample = 0.3, # randomly sample 30% of the training data for each tree, avoid overfitting
        # use_label_encoder=False,
        eval_metric='merror',
        random_state=random_state,
        n_jobs = 1
    )

    # 3. Setup StratifiedKFold
    skf = StratifiedKFold(
        n_splits=cv,
        shuffle=True,
        random_state=random_state
    )

    # 4. Setup GridSearchCV
    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        cv=skf,
        scoring='accuracy',
        n_jobs=-1, # use all the CPU cores
        verbose=2  # detailed output monitoring progress updates
    )

    # 5. Scale the features
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 6. Fit the model
    grid_search.fit(X_scaled, y_encoded)

    # 7. Best model
    best_model = grid_search.best_estimator_
    
    # 8. Best params
    best_par = grid_search.best_params_
    
    # 9. Best CV score
    best_score = grid_search.best_score_

    # 10. Feature importance
    feature_importance = pd.DataFrame({
        'feature': [f'feature_{i}' for i in range(X.shape[1])],
        'importance': best_model.feature_importances_
    })
    feature_importance = feature_importance.sort_values('importance', ascending=False)
    
    # compile and return the results
    results = {
        'best_params': best_par,
        'best_score': best_score,
        'best_model': best_model,
        'feature_importance': feature_importance
    }

    return results, grid_search

# %%
start_time = time()

XGB_result, grid_search = auto_xgboost(X=train_images_pca, y=train_Class)
  
end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# Runtime: 108.1307745218277 mins

# %%
# loop through and print the results
for key, value in XGB_result.items():
    print(f"{key}: \n {value}")
# Out:
# best_params:
#  {'colsample_bytree': 0.5, 'learning_rate': 0.05, 'max_depth': 10}
# best_score:
#  0.5069137488060953
# best_model:
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=1, num_parallel_tree=None, objective='multi:softmax', ...)
# feature_importance:
#           feature  importance
# 47    feature_47    0.013484
# 37    feature_37    0.009227
# 0      feature_0    0.008710
# 38    feature_38    0.008427
# 49    feature_49    0.008255
# ..           ...         ...
# 150  feature_150    0.005291
# 5      feature_5    0.005268
# 156  feature_156    0.005223
# 130  feature_130    0.005167
# 127  feature_127    0.005116
#
# [168 rows x 2 columns]

# %%
start_time = time()

# work on the test data set
# fit with the best model with 5000 trees

# encode the classes
label_encoder = LabelEncoder()
label_encoder.fit(train_Class)
train_Class_encoded = label_encoder.transform(train_Class)
test_Class_encoded = label_encoder.transform(test_Class)
# fit with the best model with 5000 trees

X_ttrain, X_val, y_ttrain, y_val = train_test_split(train_images_pca, train_Class_encoded, 
                                                  test_size=0.1, random_state=2024, stratify=train_Class_encoded)
    
    
xgb = XGBClassifier(max_depth=10, learning_rate=0.05,
                       random_state=2024, subsample = 0.3, n_estimators=5000, colsample_bytree=0.5,
                       objective='multi:softmax', eval_metric='merror', early_stopping_rounds=500)
xgb.fit(X_ttrain, y_ttrain, eval_set=[(X_val, y_val)])
train_Class_pred = xgb.predict(train_images_pca)
test_Class_pred = xgb.predict(test_images_pca)

end_time = time()
print(f"Runtime: {(end_time - start_time)/60} mins")
# Out:
# [0]	validation_0-merror:0.73180
# [1]	validation_0-merror:0.70115
# [2]	validation_0-merror:0.66876
# [3]	validation_0-merror:0.66318
# [4]	validation_0-merror:0.64263
# [5]	validation_0-merror:0.63706
# [6]	validation_0-merror:0.62696
# [7]	validation_0-merror:0.61755
# [8]	validation_0-merror:0.61163
# [9]	validation_0-merror:0.60954
# [10]	validation_0-merror:0.60258
# [11]	validation_0-merror:0.59526
# [12]	validation_0-merror:0.59526
# [13]	validation_0-merror:0.59039
# [14]	validation_0-merror:0.59143
# [15]	validation_0-merror:0.58621
# [16]	validation_0-merror:0.58307
# [17]	validation_0-merror:0.58063
# [18]	validation_0-merror:0.57750
# [19]	validation_0-merror:0.56949
# [20]	validation_0-merror:0.57018
# [21]	validation_0-merror:0.56949
# [22]	validation_0-merror:0.57367
# [23]	validation_0-merror:0.57158
# [24]	validation_0-merror:0.57053
# [25]	validation_0-merror:0.56809
# [26]	validation_0-merror:0.56635
# [27]	validation_0-merror:0.56670
# [28]	validation_0-merror:0.56392
# [29]	validation_0-merror:0.56148
# [30]	validation_0-merror:0.55904
# [31]	validation_0-merror:0.56287
# [32]	validation_0-merror:0.56008
# [33]	validation_0-merror:0.56113
# [34]	validation_0-merror:0.55660
# [35]	validation_0-merror:0.55312
# [36]	validation_0-merror:0.55207
# [37]	validation_0-merror:0.54824
# [38]	validation_0-merror:0.55138
# [39]	validation_0-merror:0.55103
# [40]	validation_0-merror:0.55033
# [41]	validation_0-merror:0.54302
# [42]	validation_0-merror:0.53918
# [43]	validation_0-merror:0.54267
# [44]	validation_0-merror:0.54197
# [45]	validation_0-merror:0.54093
# [46]	validation_0-merror:0.53988
# [47]	validation_0-merror:0.53918
# [48]	validation_0-merror:0.53849
# [49]	validation_0-merror:0.53675
# [50]	validation_0-merror:0.53988
# [51]	validation_0-merror:0.53884
# [52]	validation_0-merror:0.53849
# [53]	validation_0-merror:0.54162
# [54]	validation_0-merror:0.54197
# [55]	validation_0-merror:0.53988
# [56]	validation_0-merror:0.53849
# [57]	validation_0-merror:0.53710
# [58]	validation_0-merror:0.53361
# [59]	validation_0-merror:0.53326
# [60]	validation_0-merror:0.53048
# [61]	validation_0-merror:0.53257
# [62]	validation_0-merror:0.53083
# [63]	validation_0-merror:0.52734
# [64]	validation_0-merror:0.52769
# [65]	validation_0-merror:0.52839
# [66]	validation_0-merror:0.52699
# [67]	validation_0-merror:0.52560
# [68]	validation_0-merror:0.52351
# [69]	validation_0-merror:0.52525
# [70]	validation_0-merror:0.52525
# [71]	validation_0-merror:0.52247
# [72]	validation_0-merror:0.51724
# [73]	validation_0-merror:0.51898
# [74]	validation_0-merror:0.51968
# [75]	validation_0-merror:0.51863
# [76]	validation_0-merror:0.52177
# [77]	validation_0-merror:0.51759
# [78]	validation_0-merror:0.51968
# [79]	validation_0-merror:0.51689
# [80]	validation_0-merror:0.51829
# [81]	validation_0-merror:0.51515
# [82]	validation_0-merror:0.51306
# [83]	validation_0-merror:0.51062
# [84]	validation_0-merror:0.51271
# [85]	validation_0-merror:0.51306
# [86]	validation_0-merror:0.51550
# [87]	validation_0-merror:0.51445
# [88]	validation_0-merror:0.51480
# [89]	validation_0-merror:0.51341
# [90]	validation_0-merror:0.51341
# [91]	validation_0-merror:0.51376
# [92]	validation_0-merror:0.50993
# [93]	validation_0-merror:0.50958
# [94]	validation_0-merror:0.50958
# [95]	validation_0-merror:0.50958
# [96]	validation_0-merror:0.50923
# [97]	validation_0-merror:0.50958
# [98]	validation_0-merror:0.50888
# [99]	validation_0-merror:0.50714
# [100]	validation_0-merror:0.50749
# [101]	validation_0-merror:0.50610
# [102]	validation_0-merror:0.50644
# [103]	validation_0-merror:0.50749
# [104]	validation_0-merror:0.50575
# [105]	validation_0-merror:0.50575
# [106]	validation_0-merror:0.50296
# [107]	validation_0-merror:0.50331
# [108]	validation_0-merror:0.50296
# [109]	validation_0-merror:0.50435
# [110]	validation_0-merror:0.50192
# [111]	validation_0-merror:0.50157
# [112]	validation_0-merror:0.50192
# [113]	validation_0-merror:0.50296
# [114]	validation_0-merror:0.50296
# [115]	validation_0-merror:0.50052
# [116]	validation_0-merror:0.50157
# [117]	validation_0-merror:0.50052
# [118]	validation_0-merror:0.49843
# [119]	validation_0-merror:0.49878
# [120]	validation_0-merror:0.50331
# [121]	validation_0-merror:0.49983
# [122]	validation_0-merror:0.49913
# [123]	validation_0-merror:0.49948
# [124]	validation_0-merror:0.50192
# [125]	validation_0-merror:0.50017
# [126]	validation_0-merror:0.49948
# [127]	validation_0-merror:0.50122
# [128]	validation_0-merror:0.50087
# [129]	validation_0-merror:0.49843
# [130]	validation_0-merror:0.49913
# [131]	validation_0-merror:0.49948
# [132]	validation_0-merror:0.49913
# [133]	validation_0-merror:0.50017
# [134]	validation_0-merror:0.50052
# [135]	validation_0-merror:0.49983
# [136]	validation_0-merror:0.49878
# [137]	validation_0-merror:0.50157
# [138]	validation_0-merror:0.50017
# [139]	validation_0-merror:0.50261
# [140]	validation_0-merror:0.50087
# [141]	validation_0-merror:0.50122
# [142]	validation_0-merror:0.50052
# [143]	validation_0-merror:0.50192
# [144]	validation_0-merror:0.50192
# [145]	validation_0-merror:0.50122
# [146]	validation_0-merror:0.50052
# [147]	validation_0-merror:0.49983
# [148]	validation_0-merror:0.49948
# [149]	validation_0-merror:0.49704
# [150]	validation_0-merror:0.49913
# [151]	validation_0-merror:0.49983
# [152]	validation_0-merror:0.49808
# [153]	validation_0-merror:0.49808
# [154]	validation_0-merror:0.50017
# [155]	validation_0-merror:0.50017
# [156]	validation_0-merror:0.49913
# [157]	validation_0-merror:0.49878
# [673]	validation_0-merror:0.47335
# [674]	validation_0-merror:0.47475
# [675]	validation_0-merror:0.47370
# [676]	validation_0-merror:0.47161
# [677]	validation_0-merror:0.47335
# [678]	validation_0-merror:0.47057
# [679]	validation_0-merror:0.47092
# [680]	validation_0-merror:0.47161
# [681]	validation_0-merror:0.47092
# [682]	validation_0-merror:0.47092
# [683]	validation_0-merror:0.47057
# [684]	validation_0-merror:0.47126
# [685]	validation_0-merror:0.47092
# [686]	validation_0-merror:0.46987
# [687]	validation_0-merror:0.47092
# [688]	validation_0-merror:0.47022
# [689]	validation_0-merror:0.46917
# [690]	validation_0-merror:0.47057
# [691]	validation_0-merror:0.47057
# [692]	validation_0-merror:0.47022
# [693]	validation_0-merror:0.47022
# [694]	validation_0-merror:0.47057
# [695]	validation_0-merror:0.46987
# [696]	validation_0-merror:0.46813
# [697]	validation_0-merror:0.46813
# [698]	validation_0-merror:0.46848
# [699]	validation_0-merror:0.46743
# [700]	validation_0-merror:0.46743
# [701]	validation_0-merror:0.46952
# [702]	validation_0-merror:0.46917
# [703]	validation_0-merror:0.46917
# [704]	validation_0-merror:0.46848
# [705]	validation_0-merror:0.46813
# [706]	validation_0-merror:0.46917
# [707]	validation_0-merror:0.46883
# [708]	validation_0-merror:0.46883
# [709]	validation_0-merror:0.47092
# [710]	validation_0-merror:0.47092
# [711]	validation_0-merror:0.46952
# [712]	validation_0-merror:0.46987
# [713]	validation_0-merror:0.47057
# [714]	validation_0-merror:0.46952
# [715]	validation_0-merror:0.46987
# [716]	validation_0-merror:0.47022
# [717]	validation_0-merror:0.47022
# [718]	validation_0-merror:0.47057
# [719]	validation_0-merror:0.47022
# [720]	validation_0-merror:0.46987
# [721]	validation_0-merror:0.46917
# [722]	validation_0-merror:0.46952
# [723]	validation_0-merror:0.46952
# [724]	validation_0-merror:0.46883
# [725]	validation_0-merror:0.47161
# [726]	validation_0-merror:0.47092
# [727]	validation_0-merror:0.47196
# [728]	validation_0-merror:0.47161
# [729]	validation_0-merror:0.47161
# [730]	validation_0-merror:0.47126
# [731]	validation_0-merror:0.47126
# [732]	validation_0-merror:0.47161
# [733]	validation_0-merror:0.47092
# [734]	validation_0-merror:0.47196
# [735]	validation_0-merror:0.47092
# [736]	validation_0-merror:0.46987
# [737]	validation_0-merror:0.47057
# [738]	validation_0-merror:0.47126
# [739]	validation_0-merror:0.47092
# [740]	validation_0-merror:0.47022
# [741]	validation_0-merror:0.47231
# [742]	validation_0-merror:0.47196
# [743]	validation_0-merror:0.47126
# [744]	validation_0-merror:0.47092
# [745]	validation_0-merror:0.47126
# [746]	validation_0-merror:0.47022
# [747]	validation_0-merror:0.47092
# [748]	validation_0-merror:0.46987
# [749]	validation_0-merror:0.47057
# [750]	validation_0-merror:0.46952
# [751]	validation_0-merror:0.47092
# [752]	validation_0-merror:0.47022
# [753]	validation_0-merror:0.46987
# [754]	validation_0-merror:0.46917
# [755]	validation_0-merror:0.46883
# [756]	validation_0-merror:0.47057
# [757]	validation_0-merror:0.46917
# [758]	validation_0-merror:0.46917
# [759]	validation_0-merror:0.46952
# [760]	validation_0-merror:0.47022
# [761]	validation_0-merror:0.46883
# [762]	validation_0-merror:0.46883
# [763]	validation_0-merror:0.46778
# [764]	validation_0-merror:0.46813
# [765]	validation_0-merror:0.46813
# [766]	validation_0-merror:0.46883
# [767]	validation_0-merror:0.46883
# [768]	validation_0-merror:0.46917
# [769]	validation_0-merror:0.46883
# [770]	validation_0-merror:0.46883
# [771]	validation_0-merror:0.46917
# [772]	validation_0-merror:0.46848
# [773]	validation_0-merror:0.46917
# [774]	validation_0-merror:0.46917
# [775]	validation_0-merror:0.47057
# [776]	validation_0-merror:0.47057
# [777]	validation_0-merror:0.47022
# [778]	validation_0-merror:0.46987
# [779]	validation_0-merror:0.46883
# [780]	validation_0-merror:0.46883
# [781]	validation_0-merror:0.46883
# [782]	validation_0-merror:0.46883
# [783]	validation_0-merror:0.46848
# [784]	validation_0-merror:0.46848
# [785]	validation_0-merror:0.46987
# [786]	validation_0-merror:0.46917
# [787]	validation_0-merror:0.47022
# [788]	validation_0-merror:0.46883
# [789]	validation_0-merror:0.46883
# [790]	validation_0-merror:0.46917
# [791]	validation_0-merror:0.46883
# [792]	validation_0-merror:0.46917
# [793]	validation_0-merror:0.46917
# [794]	validation_0-merror:0.46848
# [795]	validation_0-merror:0.47057
# [796]	validation_0-merror:0.47092
# [797]	validation_0-merror:0.47022
# [798]	validation_0-merror:0.47057
# [799]	validation_0-merror:0.47231
# [800]	validation_0-merror:0.47161
# [801]	validation_0-merror:0.47092
# [802]	validation_0-merror:0.47092
# [803]	validation_0-merror:0.47057
# [804]	validation_0-merror:0.47057
# [805]	validation_0-merror:0.46883
# [806]	validation_0-merror:0.46952
# [807]	validation_0-merror:0.46848
# [808]	validation_0-merror:0.46813
# [809]	validation_0-merror:0.46917
# [810]	validation_0-merror:0.46987
# [811]	validation_0-merror:0.46987
# [812]	validation_0-merror:0.46917
# [813]	validation_0-merror:0.46952
# [814]	validation_0-merror:0.46952
# [815]	validation_0-merror:0.46987
# [816]	validation_0-merror:0.46987
# [817]	validation_0-merror:0.46987
# [818]	validation_0-merror:0.46987
# [819]	validation_0-merror:0.46952
# [820]	validation_0-merror:0.46883
# [821]	validation_0-merror:0.46883
# [822]	validation_0-merror:0.46848
# [823]	validation_0-merror:0.46778
# [824]	validation_0-merror:0.46883
# [825]	validation_0-merror:0.46883
# [826]	validation_0-merror:0.46848
# [827]	validation_0-merror:0.46708
# [828]	validation_0-merror:0.46778
# [829]	validation_0-merror:0.46743
# [830]	validation_0-merror:0.46778
# [831]	validation_0-merror:0.46917
# [832]	validation_0-merror:0.46917
# [833]	validation_0-merror:0.46917
# [834]	validation_0-merror:0.46917
# [835]	validation_0-merror:0.46987
# [836]	validation_0-merror:0.46987
# [837]	validation_0-merror:0.46952
# [838]	validation_0-merror:0.46917
# [839]	validation_0-merror:0.46917
# [840]	validation_0-merror:0.46987
# [841]	validation_0-merror:0.46987
# [842]	validation_0-merror:0.46987
# [843]	validation_0-merror:0.47022
# [844]	validation_0-merror:0.46883
# [845]	validation_0-merror:0.47057
# [846]	validation_0-merror:0.47092
# [847]	validation_0-merror:0.46987
# [848]	validation_0-merror:0.47057
# [849]	validation_0-merror:0.46987
# [850]	validation_0-merror:0.46987
# [851]	validation_0-merror:0.46987
# [852]	validation_0-merror:0.47092
# [853]	validation_0-merror:0.47057
# [854]	validation_0-merror:0.47022
# [855]	validation_0-merror:0.46848
# [856]	validation_0-merror:0.46848
# [857]	validation_0-merror:0.46848
# [858]	validation_0-merror:0.46743
# [859]	validation_0-merror:0.46708
# [860]	validation_0-merror:0.46743
# [861]	validation_0-merror:0.46848
# [862]	validation_0-merror:0.46883
# [863]	validation_0-merror:0.46848
# [864]	validation_0-merror:0.46848
# [865]	validation_0-merror:0.46778
# [866]	validation_0-merror:0.46778
# [867]	validation_0-merror:0.46743
# [868]	validation_0-merror:0.46778
# [869]	validation_0-merror:0.46883
# [870]	validation_0-merror:0.46848
# [871]	validation_0-merror:0.46848
# [872]	validation_0-merror:0.46743
# [873]	validation_0-merror:0.46674
# [874]	validation_0-merror:0.46639
# [875]	validation_0-merror:0.46674
# [876]	validation_0-merror:0.46674
# [877]	validation_0-merror:0.46639
# [878]	validation_0-merror:0.46534
# [879]	validation_0-merror:0.46499
# [880]	validation_0-merror:0.46534
# [881]	validation_0-merror:0.46604
# [882]	validation_0-merror:0.46639
# [883]	validation_0-merror:0.46674
# [884]	validation_0-merror:0.46743
# [885]	validation_0-merror:0.46604
# [886]	validation_0-merror:0.46743
# [887]	validation_0-merror:0.46917
# [888]	validation_0-merror:0.46848
# [889]	validation_0-merror:0.46848
# [890]	validation_0-merror:0.46743
# [891]	validation_0-merror:0.46708
# [892]	validation_0-merror:0.46708
# [893]	validation_0-merror:0.46604
# [894]	validation_0-merror:0.46708
# [895]	validation_0-merror:0.46708
# [896]	validation_0-merror:0.46534
# [897]	validation_0-merror:0.46569
# [898]	validation_0-merror:0.46743
# [899]	validation_0-merror:0.47022
# [900]	validation_0-merror:0.46848
# [901]	validation_0-merror:0.46848
# [902]	validation_0-merror:0.46813
# [903]	validation_0-merror:0.46813
# [904]	validation_0-merror:0.46883
# [905]	validation_0-merror:0.46743
# [906]	validation_0-merror:0.46743
# [907]	validation_0-merror:0.46708
# [908]	validation_0-merror:0.46778
# [909]	validation_0-merror:0.46743
# [910]	validation_0-merror:0.46778
# [911]	validation_0-merror:0.46778
# [912]	validation_0-merror:0.46708
# [913]	validation_0-merror:0.46743
# [914]	validation_0-merror:0.46674
# [915]	validation_0-merror:0.46534
# [916]	validation_0-merror:0.46743
# [917]	validation_0-merror:0.46639
# [918]	validation_0-merror:0.46778
# [919]	validation_0-merror:0.46743
# [920]	validation_0-merror:0.46674
# [921]	validation_0-merror:0.46639
# [922]	validation_0-merror:0.46499
# [923]	validation_0-merror:0.46465
# [924]	validation_0-merror:0.46465
# [925]	validation_0-merror:0.46534
# [926]	validation_0-merror:0.46465
# [927]	validation_0-merror:0.46395
# [928]	validation_0-merror:0.46569
# [929]	validation_0-merror:0.46569
# [1977]	validation_0-merror:0.46047
# [1978]	validation_0-merror:0.45977
# [1979]	validation_0-merror:0.46047
# [1980]	validation_0-merror:0.46047
# [1981]	validation_0-merror:0.46082
# [1982]	validation_0-merror:0.46047
# [1983]	validation_0-merror:0.46082
# [1984]	validation_0-merror:0.46082
# [1985]	validation_0-merror:0.46116
# [1986]	validation_0-merror:0.46151
# [1987]	validation_0-merror:0.46116
# [1988]	validation_0-merror:0.46186
# [1989]	validation_0-merror:0.46186
# [1990]	validation_0-merror:0.46082
# [1991]	validation_0-merror:0.46082
# [1992]	validation_0-merror:0.46047
# [1993]	validation_0-merror:0.46047
# [1994]	validation_0-merror:0.46116
# [1995]	validation_0-merror:0.46116
# [1996]	validation_0-merror:0.46151
# [1997]	validation_0-merror:0.46151
# [1998]	validation_0-merror:0.46221
# [1999]	validation_0-merror:0.46221
# [2000]	validation_0-merror:0.46325
# [2001]	validation_0-merror:0.46290
# [2002]	validation_0-merror:0.46256
# [2003]	validation_0-merror:0.46221
# [2004]	validation_0-merror:0.46290
# [2005]	validation_0-merror:0.46221
# [2006]	validation_0-merror:0.46290
# [2007]	validation_0-merror:0.46151
# [2008]	validation_0-merror:0.46256
# [2009]	validation_0-merror:0.46256
# [2010]	validation_0-merror:0.46221
# [2011]	validation_0-merror:0.46221
# [2012]	validation_0-merror:0.46186
# [2013]	validation_0-merror:0.46151
# [2014]	validation_0-merror:0.46186
# [2015]	validation_0-merror:0.46221
# [2016]	validation_0-merror:0.46221
# [2017]	validation_0-merror:0.46082
# [2018]	validation_0-merror:0.46047
# [2019]	validation_0-merror:0.46151
# [2020]	validation_0-merror:0.46151
# [2021]	validation_0-merror:0.46151
# [2022]	validation_0-merror:0.46151
# [2023]	validation_0-merror:0.46186
# [2024]	validation_0-merror:0.46186
# [2025]	validation_0-merror:0.46151
# [2026]	validation_0-merror:0.46221
# [2027]	validation_0-merror:0.46221
# [2028]	validation_0-merror:0.46290
# [2029]	validation_0-merror:0.46256
# [2030]	validation_0-merror:0.46290
# [2031]	validation_0-merror:0.46325
# [2032]	validation_0-merror:0.46256
# [2033]	validation_0-merror:0.46256
# [2034]	validation_0-merror:0.46151
# [2035]	validation_0-merror:0.46256
# [2036]	validation_0-merror:0.46151
# [2037]	validation_0-merror:0.46151
# [2038]	validation_0-merror:0.46116
# [2039]	validation_0-merror:0.46221
# [2040]	validation_0-merror:0.46186
# [2041]	validation_0-merror:0.46151
# [2042]	validation_0-merror:0.46047
# [2043]	validation_0-merror:0.46047
# [2044]	validation_0-merror:0.46047
# [2045]	validation_0-merror:0.46186
# [2046]	validation_0-merror:0.46116
# [2047]	validation_0-merror:0.46082
# [2048]	validation_0-merror:0.45977
# [2049]	validation_0-merror:0.46012
# [2050]	validation_0-merror:0.46047
# [2051]	validation_0-merror:0.46012
# [2052]	validation_0-merror:0.46082
# [2053]	validation_0-merror:0.46116
# [2054]	validation_0-merror:0.46116
# [2055]	validation_0-merror:0.46151
# [2056]	validation_0-merror:0.46082
# [2057]	validation_0-merror:0.46082
# [2058]	validation_0-merror:0.46116
# [2059]	validation_0-merror:0.46082
# [2060]	validation_0-merror:0.46047
# [2061]	validation_0-merror:0.45977
# [2062]	validation_0-merror:0.45977
# [2063]	validation_0-merror:0.45838
# [2064]	validation_0-merror:0.45873
# [2065]	validation_0-merror:0.45838
# [2066]	validation_0-merror:0.45873
# [2067]	validation_0-merror:0.45873
# [2068]	validation_0-merror:0.45942
# [2069]	validation_0-merror:0.45873
# [2070]	validation_0-merror:0.45907
# [2071]	validation_0-merror:0.45907
# [2072]	validation_0-merror:0.45873
# [2073]	validation_0-merror:0.45907
# [2074]	validation_0-merror:0.45977
# [2075]	validation_0-merror:0.45942
# [2076]	validation_0-merror:0.45977
# [2077]	validation_0-merror:0.45977
# [2078]	validation_0-merror:0.45907
# [2079]	validation_0-merror:0.45942
# [2080]	validation_0-merror:0.46012
# [2081]	validation_0-merror:0.45942
# [2082]	validation_0-merror:0.45873
# [2083]	validation_0-merror:0.45803
# [2084]	validation_0-merror:0.45873
# [2085]	validation_0-merror:0.45873
# [2086]	validation_0-merror:0.45803
# [2087]	validation_0-merror:0.45803
# [2088]	validation_0-merror:0.45803
# Runtime: 3.586022102832794 mins

# %%
# train accuracy
print(accuracy_score(train_Class_encoded, train_Class_pred))
        
# classification_report
print(classification_report(train_Class_encoded, train_Class_pred))
# Out:
# 0.9528022571319098
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      3995
#            1       1.00      0.92      0.96       436
#            2       0.96      0.93      0.95      4097
#            3       0.95      0.98      0.96      7215
#            4       0.95      0.95      0.95      4965
#            5       0.94      0.94      0.94      4830
#            6       0.97      0.96      0.97      3171
#
#     accuracy                           0.95     28709
#    macro avg       0.96      0.95      0.95     28709
# weighted avg       0.95      0.95      0.95     28709

# %%
# train accuracy
print(accuracy_score(test_Class_encoded, test_Class_pred))
        
# classification_report
print(classification_report(test_Class_encoded, test_Class_pred))
# Out:
# 0.5380328782390638
#               precision    recall  f1-score   support
#
#            0       0.46      0.34      0.39       958
#            1       0.95      0.32      0.48       111
#            2       0.49      0.35      0.41      1024
#            3       0.61      0.80      0.69      1774
#            4       0.46      0.53      0.49      1233
#            5       0.42      0.41      0.42      1247
#            6       0.76      0.66      0.71       831
#
#     accuracy                           0.54      7178
#    macro avg       0.59      0.49      0.51      7178
# weighted avg       0.54      0.54      0.53      7178

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# comfusion matrix
test_Class_pred = label_encoder.inverse_transform(test_Class_pred) 
cm = confusion_matrix(test_Class, test_Class_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
# Create the heatmap with annotations as percentages
class_names = ["angry", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized*100, annot=True, fmt='.4', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)  # Format as percentages with 2 decimal places
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix (Percentages) (HOG & PCA + Gabor Filter & PCA + XGBoost)')
plt.show()
