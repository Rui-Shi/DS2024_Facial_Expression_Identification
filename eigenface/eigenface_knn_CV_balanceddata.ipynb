# %%
import numpy as np
import pandas as pd
import os
import cv2
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from eigenface_project import eigenface_project
from sklearn.metrics import classification_report
# numbers of pixels of x and y axis
xPixel = 48  
yPixel = 48

# %%
# Load the raw data
# df = pd.read_csv("../row_data_to_csv/train_data/face_data_train.csv", header=0) # specify the first row as header

# %%
# Directory paths
train_dir = os.path.expanduser('../train_balanced')

# Define a function to load the balanced data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)

print(f"Loaded {len(train_images)} training images.")
# Out:
# Loaded 34795 training images.

# %%
{x: train_labels.count(x) for x in set(train_labels)}
print(np.array(train_images).shape)
# Out:
# (34795, 48, 48)

# %%
# set up X, y
Class = np.array(train_labels)
train_images = np.array(train_images)

# %%
# the projection of the image data on the eigen vectors
train_images_project, selected_eigenvectors=eigenface_project(train_images)

# %%
# Perform StratifiedKFold cross-validation on knn

# create pipeline object
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# Define the parameter grid for n_neighbors
param_grid = {
    'knn__n_neighbors': range(1, 201)  # Test n_neighbors from 1 to 30
}

# stratified CV object
skcv = StratifiedKFold(n_splits=10, shuffle=True, random_state=2024)

# Initialize GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=skcv, scoring='accuracy')

# Fit the grid search
grid_search.fit(train_images_project, Class)

# Print the results
# Print the best n_neighbors and the corresponding score
print("Best n_neighbors:", grid_search.best_params_['knn__n_neighbors'])
print("Best accuracy:", grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 21
#      18 grid_search = GridSearchCV(pipeline, param_grid, cv=skcv, scoring='accuracy')
#      20 # Fit the grid search
# ---> 21 grid_search.fit(train_images_project, Class)
#      23 # Print the results
#      24 # Print the best n_neighbors and the corresponding score
#      25 print("Best n_neighbors:", grid_search.best_params_['knn__n_neighbors'])
#
# File c:\Users\shiru\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\shiru\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:922, in BaseSearchCV.fit(self, X, y, **params)
#     919 estimator = self.estimator
#     920 scorers, refit_metric = self._get_scorers()
# --> 922 X, y = indexable(X, y)
#     923 params = _check_method_params(X, params=params)
#     925 routed_params = self._get_routed_params_for_fit(params)
#
# File c:\Users\shiru\anaconda3\Lib\site-packages\sklearn\utils\validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File c:\Users\shiru\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [2, 34795]

# %%
# Print the results for each n_neighbors
for i in range(1, 201):
    print(f"n_neighbors = {i}:")
    print(f"  Mean cross-validation score: {grid_search.cv_results_[f'mean_test_score'][i-1]:.4f}")
    # print(f"  Standard deviation: {grid_search.cv_results_[f'std_test_score'][i-1]:.4f}")
# Out:
# n_neighbors = 1:
#   Mean cross-validation score: 0.3866
# n_neighbors = 2:
#   Mean cross-validation score: 0.3415
# n_neighbors = 3:
#   Mean cross-validation score: 0.3429
# n_neighbors = 4:
#   Mean cross-validation score: 0.3443
# n_neighbors = 5:
#   Mean cross-validation score: 0.3440
# n_neighbors = 6:
#   Mean cross-validation score: 0.3403
# n_neighbors = 7:
#   Mean cross-validation score: 0.3364
# n_neighbors = 8:
#   Mean cross-validation score: 0.3366
# n_neighbors = 9:
#   Mean cross-validation score: 0.3376
# n_neighbors = 10:
#   Mean cross-validation score: 0.3354
# n_neighbors = 11:
#   Mean cross-validation score: 0.3348
# n_neighbors = 12:
#   Mean cross-validation score: 0.3332
# n_neighbors = 13:
#   Mean cross-validation score: 0.3310
# n_neighbors = 14:
#   Mean cross-validation score: 0.3286
# n_neighbors = 15:
#   Mean cross-validation score: 0.3287
# n_neighbors = 16:
#   Mean cross-validation score: 0.3264
# n_neighbors = 17:
#   Mean cross-validation score: 0.3259
# n_neighbors = 18:
#   Mean cross-validation score: 0.3247
# n_neighbors = 19:
#   Mean cross-validation score: 0.3231
# n_neighbors = 20:
#   Mean cross-validation score: 0.3217
# n_neighbors = 21:
#   Mean cross-validation score: 0.3218
# n_neighbors = 22:
#   Mean cross-validation score: 0.3201
# n_neighbors = 23:
#   Mean cross-validation score: 0.3195
# n_neighbors = 24:
#   Mean cross-validation score: 0.3175
# n_neighbors = 25:
#   Mean cross-validation score: 0.3167
# n_neighbors = 26:
#   Mean cross-validation score: 0.3164
# n_neighbors = 27:
#   Mean cross-validation score: 0.3144
# n_neighbors = 28:
#   Mean cross-validation score: 0.3126
# n_neighbors = 29:
#   Mean cross-validation score: 0.3120
# n_neighbors = 30:
#   Mean cross-validation score: 0.3111
# n_neighbors = 31:
#   Mean cross-validation score: 0.3119
# n_neighbors = 32:
#   Mean cross-validation score: 0.3115
# n_neighbors = 33:
#   Mean cross-validation score: 0.3127
# n_neighbors = 34:
#   Mean cross-validation score: 0.3133
# n_neighbors = 35:
#   Mean cross-validation score: 0.3129
# n_neighbors = 36:
#   Mean cross-validation score: 0.3119
# n_neighbors = 37:
#   Mean cross-validation score: 0.3101
# n_neighbors = 38:
#   Mean cross-validation score: 0.3095
# n_neighbors = 39:
#   Mean cross-validation score: 0.3089
# n_neighbors = 40:
#   Mean cross-validation score: 0.3096
# n_neighbors = 41:
#   Mean cross-validation score: 0.3099
# n_neighbors = 42:
#   Mean cross-validation score: 0.3085
# n_neighbors = 43:
#   Mean cross-validation score: 0.3083
# n_neighbors = 44:
#   Mean cross-validation score: 0.3069
# n_neighbors = 45:
#   Mean cross-validation score: 0.3072
# n_neighbors = 46:
#   Mean cross-validation score: 0.3054
# n_neighbors = 47:
#   Mean cross-validation score: 0.3055
# n_neighbors = 48:
#   Mean cross-validation score: 0.3061
# n_neighbors = 49:
#   Mean cross-validation score: 0.3062
# n_neighbors = 50:
#   Mean cross-validation score: 0.3049
# n_neighbors = 51:
#   Mean cross-validation score: 0.3050
# n_neighbors = 52:
#   Mean cross-validation score: 0.3054
# n_neighbors = 53:
#   Mean cross-validation score: 0.3047
# n_neighbors = 54:
#   Mean cross-validation score: 0.3044
# n_neighbors = 55:
#   Mean cross-validation score: 0.3049
# n_neighbors = 56:
#   Mean cross-validation score: 0.3041
# n_neighbors = 57:
#   Mean cross-validation score: 0.3037
# n_neighbors = 58:
#   Mean cross-validation score: 0.3022
# n_neighbors = 59:
#   Mean cross-validation score: 0.3015
# n_neighbors = 60:
#   Mean cross-validation score: 0.3015
# n_neighbors = 61:
#   Mean cross-validation score: 0.3007
# n_neighbors = 62:
#   Mean cross-validation score: 0.3006
# n_neighbors = 63:
#   Mean cross-validation score: 0.2998
# n_neighbors = 64:
#   Mean cross-validation score: 0.2991
# n_neighbors = 65:
#   Mean cross-validation score: 0.2981
# n_neighbors = 66:
#   Mean cross-validation score: 0.2984
# n_neighbors = 67:
#   Mean cross-validation score: 0.2980
# n_neighbors = 68:
#   Mean cross-validation score: 0.2965
# n_neighbors = 69:
#   Mean cross-validation score: 0.2963
# n_neighbors = 70:
#   Mean cross-validation score: 0.2958
# n_neighbors = 71:
#   Mean cross-validation score: 0.2956
# n_neighbors = 72:
#   Mean cross-validation score: 0.2955
# n_neighbors = 73:
#   Mean cross-validation score: 0.2955
# n_neighbors = 74:
#   Mean cross-validation score: 0.2949
# n_neighbors = 75:
#   Mean cross-validation score: 0.2946
# n_neighbors = 76:
#   Mean cross-validation score: 0.2931
# n_neighbors = 77:
#   Mean cross-validation score: 0.2924
# n_neighbors = 78:
#   Mean cross-validation score: 0.2929
# n_neighbors = 79:
#   Mean cross-validation score: 0.2918
# n_neighbors = 80:
#   Mean cross-validation score: 0.2924
# n_neighbors = 81:
#   Mean cross-validation score: 0.2922
# n_neighbors = 82:
#   Mean cross-validation score: 0.2918
# n_neighbors = 83:
#   Mean cross-validation score: 0.2913
# n_neighbors = 84:
#   Mean cross-validation score: 0.2905
# n_neighbors = 85:
#   Mean cross-validation score: 0.2890
# n_neighbors = 86:
#   Mean cross-validation score: 0.2887
# n_neighbors = 87:
#   Mean cross-validation score: 0.2892
# n_neighbors = 88:
#   Mean cross-validation score: 0.2889
# n_neighbors = 89:
#   Mean cross-validation score: 0.2883
# n_neighbors = 90:
#   Mean cross-validation score: 0.2879
# n_neighbors = 91:
#   Mean cross-validation score: 0.2879
# n_neighbors = 92:
#   Mean cross-validation score: 0.2877
# n_neighbors = 93:
#   Mean cross-validation score: 0.2879
# n_neighbors = 94:
#   Mean cross-validation score: 0.2879
# n_neighbors = 95:
#   Mean cross-validation score: 0.2871
# n_neighbors = 96:
#   Mean cross-validation score: 0.2873
# n_neighbors = 97:
#   Mean cross-validation score: 0.2871
# n_neighbors = 98:
#   Mean cross-validation score: 0.2871
# n_neighbors = 99:
#   Mean cross-validation score: 0.2867
# n_neighbors = 100:
#   Mean cross-validation score: 0.2862
# n_neighbors = 101:
#   Mean cross-validation score: 0.2861
# n_neighbors = 102:
#   Mean cross-validation score: 0.2850
# n_neighbors = 103:
#   Mean cross-validation score: 0.2850
# n_neighbors = 104:
#   Mean cross-validation score: 0.2853
# n_neighbors = 105:
#   Mean cross-validation score: 0.2845
# n_neighbors = 106:
#   Mean cross-validation score: 0.2843
# n_neighbors = 107:
#   Mean cross-validation score: 0.2842
# n_neighbors = 108:
#   Mean cross-validation score: 0.2838
# n_neighbors = 109:
#   Mean cross-validation score: 0.2837
# n_neighbors = 110:
#   Mean cross-validation score: 0.2838
# n_neighbors = 111:
#   Mean cross-validation score: 0.2836
# n_neighbors = 112:
#   Mean cross-validation score: 0.2835
# n_neighbors = 113:
#   Mean cross-validation score: 0.2830
# n_neighbors = 114:
#   Mean cross-validation score: 0.2825
# n_neighbors = 115:
#   Mean cross-validation score: 0.2820
# n_neighbors = 116:
#   Mean cross-validation score: 0.2820
# n_neighbors = 117:
#   Mean cross-validation score: 0.2814
# n_neighbors = 118:
#   Mean cross-validation score: 0.2817
# n_neighbors = 119:
#   Mean cross-validation score: 0.2807
# n_neighbors = 120:
#   Mean cross-validation score: 0.2804
# n_neighbors = 121:
#   Mean cross-validation score: 0.2800
# n_neighbors = 122:
#   Mean cross-validation score: 0.2797
# n_neighbors = 123:
#   Mean cross-validation score: 0.2792
# n_neighbors = 124:
#   Mean cross-validation score: 0.2793
# n_neighbors = 125:
#   Mean cross-validation score: 0.2788
# n_neighbors = 126:
#   Mean cross-validation score: 0.2787
# n_neighbors = 127:
#   Mean cross-validation score: 0.2781
# n_neighbors = 128:
#   Mean cross-validation score: 0.2787
# n_neighbors = 129:
#   Mean cross-validation score: 0.2787
# n_neighbors = 130:
#   Mean cross-validation score: 0.2786
# n_neighbors = 131:
#   Mean cross-validation score: 0.2778
# n_neighbors = 132:
#   Mean cross-validation score: 0.2773
# n_neighbors = 133:
#   Mean cross-validation score: 0.2758
# n_neighbors = 134:
#   Mean cross-validation score: 0.2754
# n_neighbors = 135:
#   Mean cross-validation score: 0.2759
# n_neighbors = 136:
#   Mean cross-validation score: 0.2759
# n_neighbors = 137:
#   Mean cross-validation score: 0.2753
# n_neighbors = 138:
#   Mean cross-validation score: 0.2749
# n_neighbors = 139:
#   Mean cross-validation score: 0.2750
# n_neighbors = 140:
#   Mean cross-validation score: 0.2743
# n_neighbors = 141:
#   Mean cross-validation score: 0.2736
# n_neighbors = 142:
#   Mean cross-validation score: 0.2736
# n_neighbors = 143:
#   Mean cross-validation score: 0.2737
# n_neighbors = 144:
#   Mean cross-validation score: 0.2729
# n_neighbors = 145:
#   Mean cross-validation score: 0.2724
# n_neighbors = 146:
#   Mean cross-validation score: 0.2727
# n_neighbors = 147:
#   Mean cross-validation score: 0.2718
# n_neighbors = 148:
#   Mean cross-validation score: 0.2722
# n_neighbors = 149:
#   Mean cross-validation score: 0.2720
# n_neighbors = 150:
#   Mean cross-validation score: 0.2724
# n_neighbors = 151:
#   Mean cross-validation score: 0.2714
# n_neighbors = 152:
#   Mean cross-validation score: 0.2712
# n_neighbors = 153:
#   Mean cross-validation score: 0.2707
# n_neighbors = 154:
#   Mean cross-validation score: 0.2700
# n_neighbors = 155:
#   Mean cross-validation score: 0.2697
# n_neighbors = 156:
#   Mean cross-validation score: 0.2699
# n_neighbors = 157:
#   Mean cross-validation score: 0.2700
# n_neighbors = 158:
#   Mean cross-validation score: 0.2693
# n_neighbors = 159:
#   Mean cross-validation score: 0.2693
# n_neighbors = 160:
#   Mean cross-validation score: 0.2689
# n_neighbors = 161:
#   Mean cross-validation score: 0.2690
# n_neighbors = 162:
#   Mean cross-validation score: 0.2691
# n_neighbors = 163:
#   Mean cross-validation score: 0.2689
# n_neighbors = 164:
#   Mean cross-validation score: 0.2685
# n_neighbors = 165:
#   Mean cross-validation score: 0.2681
# n_neighbors = 166:
#   Mean cross-validation score: 0.2678
# n_neighbors = 167:
#   Mean cross-validation score: 0.2675
# n_neighbors = 168:
#   Mean cross-validation score: 0.2676
# n_neighbors = 169:
#   Mean cross-validation score: 0.2681
# n_neighbors = 170:
#   Mean cross-validation score: 0.2672
# n_neighbors = 171:
#   Mean cross-validation score: 0.2666
# n_neighbors = 172:
#   Mean cross-validation score: 0.2669
# n_neighbors = 173:
#   Mean cross-validation score: 0.2664
# n_neighbors = 174:
#   Mean cross-validation score: 0.2668
# n_neighbors = 175:
#   Mean cross-validation score: 0.2666
# n_neighbors = 176:
#   Mean cross-validation score: 0.2664
# n_neighbors = 177:
#   Mean cross-validation score: 0.2661
# n_neighbors = 178:
#   Mean cross-validation score: 0.2657
# n_neighbors = 179:
#   Mean cross-validation score: 0.2657
# n_neighbors = 180:
#   Mean cross-validation score: 0.2657
# n_neighbors = 181:
#   Mean cross-validation score: 0.2655
# n_neighbors = 182:
#   Mean cross-validation score: 0.2652
# n_neighbors = 183:
#   Mean cross-validation score: 0.2651
# n_neighbors = 184:
#   Mean cross-validation score: 0.2644
# n_neighbors = 185:
#   Mean cross-validation score: 0.2646
# n_neighbors = 186:
#   Mean cross-validation score: 0.2643
# n_neighbors = 187:
#   Mean cross-validation score: 0.2639
# n_neighbors = 188:
#   Mean cross-validation score: 0.2637
# n_neighbors = 189:
#   Mean cross-validation score: 0.2639
# n_neighbors = 190:
#   Mean cross-validation score: 0.2629
# n_neighbors = 191:
#   Mean cross-validation score: 0.2624
# n_neighbors = 192:
#   Mean cross-validation score: 0.2625
# n_neighbors = 193:
#   Mean cross-validation score: 0.2626
# n_neighbors = 194:
#   Mean cross-validation score: 0.2628
# n_neighbors = 195:
#   Mean cross-validation score: 0.2622
# n_neighbors = 196:
#   Mean cross-validation score: 0.2620
# n_neighbors = 197:
#   Mean cross-validation score: 0.2615
# n_neighbors = 198:
#   Mean cross-validation score: 0.2615
# n_neighbors = 199:
#   Mean cross-validation score: 0.2608
# n_neighbors = 200:
#   Mean cross-validation score: 0.2606

# %%
# return the precision, recall and f1-score in each class

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=grid_search.best_params_['knn__n_neighbors']))
])

# Get predictions using cross validation
predictions = cross_val_predict(pipeline, train_images_project, Class, cv=skcv)

# Print detailed classification report
print(classification_report(Class, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.34      0.26      0.30      5000
#      disgust       0.50      0.66      0.57      5000
#         fear       0.34      0.32      0.33      5000
#        happy       0.40      0.31      0.34      5000
#      neutral       0.29      0.44      0.35      4965
#          sad       0.33      0.28      0.30      4830
#     surprise       0.51      0.44      0.47      5000
#
#     accuracy                           0.39     34795
#    macro avg       0.39      0.39      0.38     34795
# weighted avg       0.39      0.39      0.38     34795
