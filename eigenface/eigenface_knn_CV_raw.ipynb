# %%
import numpy as np
import pandas as pd
import os
import cv2
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_predict, cross_val_score, KFold, StratifiedKFold, train_test_split
from eigenface_project import eigenface_project
from sklearn.metrics import classification_report, accuracy_score
# numbers of pixels of x and y axis
xPixel = 48  
yPixel = 48

# %%
# Load the raw data
# df = pd.read_csv("../row_data_to_csv/train_data/face_data_train.csv", header=0) # specify the first row as header

# %%
# Directory paths
train_dir = os.path.expanduser('../raw_data/fer2013/train')
test_dir = os.path.expanduser('../raw_data/fer2013/test')

# Define a function to load the balanced data
def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for file in os.listdir(label_path):
                file_path = os.path.join(label_path, file)
                image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
                images.append(image)
                labels.append(label)
    return images, labels

# Load training and testing images
train_images, train_labels = load_images_from_directory(train_dir)
test_images, test_labels = load_images_from_directory(test_dir)


print(f"Loaded {len(train_images)} training images.")
print(f"Loaded {len(test_images)} training images.")
# Out:
# Loaded 28709 training images.
# Loaded 7178 training images.

# %%
# Check the train and test data
{x: train_labels.count(x) for x in set(train_labels)}
print(np.array(train_images).shape)

print({x: test_labels.count(x) for x in set(test_labels)})
print(np.array(test_images).shape)
# Out:
# (28709, 48, 48)
# {'happy': 1774, 'fear': 1024, 'surprise': 831, 'sad': 1247, 'angry': 958, 'disgust': 111, 'neutral': 1233}
# (7178, 48, 48)

# %%
# set up X, y of train and test
train_Class = np.array(train_labels)
train_images = np.array(train_images)

test_Class = np.array(test_labels)
test_images = np.array(test_images)

# %%
# project the image data on the eigen vectors
train_images_project, selected_eigenvectors=eigenface_project(train_images)

test_images_centered = test_images - np.mean(test_images, axis=0)
test_images_project = np.dot(test_images_centered.reshape(test_images.shape[0], -1), selected_eigenvectors)

# %%
# Perform StratifiedKFold cross-validation on knn

# create pipeline object
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# Define the parameter grid for n_neighbors
param_grid = {
    'knn__n_neighbors': range(1, 201)  # Test n_neighbors from 1 to 30
}

# stratified CV object
skcv = StratifiedKFold(n_splits=10, shuffle=True, random_state=2024)

# Initialize GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=skcv, scoring='accuracy')

# Fit the grid search
grid_search.fit(train_images_project, train_Class)

# Print the results
# Print the best n_neighbors and the corresponding score
print("Best n_neighbors:", grid_search.best_params_['knn__n_neighbors'])
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best n_neighbors: 1
# Best accuracy: 0.38311971086571595

# %%
# Print the results for each n_neighbors
for i in range(1, 201):
    print(f"n_neighbors = {i}:")
    print(f"  Mean cross-validation score: {grid_search.cv_results_[f'mean_test_score'][i-1]:.4f}")
    # print(f"  Standard deviation: {grid_search.cv_results_[f'std_test_score'][i-1]:.4f}")
# Out:
# n_neighbors = 1:
#   Mean cross-validation score: 0.3831
# n_neighbors = 2:
#   Mean cross-validation score: 0.3378
# n_neighbors = 3:
#   Mean cross-validation score: 0.3355
# n_neighbors = 4:
#   Mean cross-validation score: 0.3356
# n_neighbors = 5:
#   Mean cross-validation score: 0.3383
# n_neighbors = 6:
#   Mean cross-validation score: 0.3324
# n_neighbors = 7:
#   Mean cross-validation score: 0.3302
# n_neighbors = 8:
#   Mean cross-validation score: 0.3287
# n_neighbors = 9:
#   Mean cross-validation score: 0.3291
# n_neighbors = 10:
#   Mean cross-validation score: 0.3247
# n_neighbors = 11:
#   Mean cross-validation score: 0.3261
# n_neighbors = 12:
#   Mean cross-validation score: 0.3242
# n_neighbors = 13:
#   Mean cross-validation score: 0.3234
# n_neighbors = 14:
#   Mean cross-validation score: 0.3213
# n_neighbors = 15:
#   Mean cross-validation score: 0.3214
# n_neighbors = 16:
#   Mean cross-validation score: 0.3206
# n_neighbors = 17:
#   Mean cross-validation score: 0.3185
# n_neighbors = 18:
#   Mean cross-validation score: 0.3174
# n_neighbors = 19:
#   Mean cross-validation score: 0.3175
# n_neighbors = 20:
#   Mean cross-validation score: 0.3170
# n_neighbors = 21:
#   Mean cross-validation score: 0.3142
# n_neighbors = 22:
#   Mean cross-validation score: 0.3140
# n_neighbors = 23:
#   Mean cross-validation score: 0.3133
# n_neighbors = 24:
#   Mean cross-validation score: 0.3120
# n_neighbors = 25:
#   Mean cross-validation score: 0.3107
# n_neighbors = 26:
#   Mean cross-validation score: 0.3106
# n_neighbors = 27:
#   Mean cross-validation score: 0.3095
# n_neighbors = 28:
#   Mean cross-validation score: 0.3083
# n_neighbors = 29:
#   Mean cross-validation score: 0.3072
# n_neighbors = 30:
#   Mean cross-validation score: 0.3061
# n_neighbors = 31:
#   Mean cross-validation score: 0.3057
# n_neighbors = 32:
#   Mean cross-validation score: 0.3032
# n_neighbors = 33:
#   Mean cross-validation score: 0.3031
# n_neighbors = 34:
#   Mean cross-validation score: 0.3023
# n_neighbors = 35:
#   Mean cross-validation score: 0.3016
# n_neighbors = 36:
#   Mean cross-validation score: 0.3020
# n_neighbors = 37:
#   Mean cross-validation score: 0.3006
# n_neighbors = 38:
#   Mean cross-validation score: 0.3013
# n_neighbors = 39:
#   Mean cross-validation score: 0.3005
# n_neighbors = 40:
#   Mean cross-validation score: 0.3009
# n_neighbors = 41:
#   Mean cross-validation score: 0.3008
# n_neighbors = 42:
#   Mean cross-validation score: 0.3008
# n_neighbors = 43:
#   Mean cross-validation score: 0.2997
# n_neighbors = 44:
#   Mean cross-validation score: 0.2990
# n_neighbors = 45:
#   Mean cross-validation score: 0.2984
# n_neighbors = 46:
#   Mean cross-validation score: 0.2966
# n_neighbors = 47:
#   Mean cross-validation score: 0.2958
# n_neighbors = 48:
#   Mean cross-validation score: 0.2953
# n_neighbors = 49:
#   Mean cross-validation score: 0.2954
# n_neighbors = 50:
#   Mean cross-validation score: 0.2934
# n_neighbors = 51:
#   Mean cross-validation score: 0.2935
# n_neighbors = 52:
#   Mean cross-validation score: 0.2918
# n_neighbors = 53:
#   Mean cross-validation score: 0.2922
# n_neighbors = 54:
#   Mean cross-validation score: 0.2922
# n_neighbors = 55:
#   Mean cross-validation score: 0.2907
# n_neighbors = 56:
#   Mean cross-validation score: 0.2912
# n_neighbors = 57:
#   Mean cross-validation score: 0.2911
# n_neighbors = 58:
#   Mean cross-validation score: 0.2912
# n_neighbors = 59:
#   Mean cross-validation score: 0.2910
# n_neighbors = 60:
#   Mean cross-validation score: 0.2895
# n_neighbors = 61:
#   Mean cross-validation score: 0.2898
# n_neighbors = 62:
#   Mean cross-validation score: 0.2900
# n_neighbors = 63:
#   Mean cross-validation score: 0.2880
# n_neighbors = 64:
#   Mean cross-validation score: 0.2877
# n_neighbors = 65:
#   Mean cross-validation score: 0.2885
# n_neighbors = 66:
#   Mean cross-validation score: 0.2869
# n_neighbors = 67:
#   Mean cross-validation score: 0.2867
# n_neighbors = 68:
#   Mean cross-validation score: 0.2859
# n_neighbors = 69:
#   Mean cross-validation score: 0.2851
# n_neighbors = 70:
#   Mean cross-validation score: 0.2852
# n_neighbors = 71:
#   Mean cross-validation score: 0.2852
# n_neighbors = 72:
#   Mean cross-validation score: 0.2840
# n_neighbors = 73:
#   Mean cross-validation score: 0.2844
# n_neighbors = 74:
#   Mean cross-validation score: 0.2845
# n_neighbors = 75:
#   Mean cross-validation score: 0.2839
# n_neighbors = 76:
#   Mean cross-validation score: 0.2832
# n_neighbors = 77:
#   Mean cross-validation score: 0.2831
# n_neighbors = 78:
#   Mean cross-validation score: 0.2823
# n_neighbors = 79:
#   Mean cross-validation score: 0.2825
# n_neighbors = 80:
#   Mean cross-validation score: 0.2822
# n_neighbors = 81:
#   Mean cross-validation score: 0.2820
# n_neighbors = 82:
#   Mean cross-validation score: 0.2821
# n_neighbors = 83:
#   Mean cross-validation score: 0.2807
# n_neighbors = 84:
#   Mean cross-validation score: 0.2812
# n_neighbors = 85:
#   Mean cross-validation score: 0.2812
# n_neighbors = 86:
#   Mean cross-validation score: 0.2808
# n_neighbors = 87:
#   Mean cross-validation score: 0.2809
# n_neighbors = 88:
#   Mean cross-validation score: 0.2805
# n_neighbors = 89:
#   Mean cross-validation score: 0.2788
# n_neighbors = 90:
#   Mean cross-validation score: 0.2793
# n_neighbors = 91:
#   Mean cross-validation score: 0.2795
# n_neighbors = 92:
#   Mean cross-validation score: 0.2791
# n_neighbors = 93:
#   Mean cross-validation score: 0.2784
# n_neighbors = 94:
#   Mean cross-validation score: 0.2780
# n_neighbors = 95:
#   Mean cross-validation score: 0.2784
# n_neighbors = 96:
#   Mean cross-validation score: 0.2784
# n_neighbors = 97:
#   Mean cross-validation score: 0.2764
# n_neighbors = 98:
#   Mean cross-validation score: 0.2766
# n_neighbors = 99:
#   Mean cross-validation score: 0.2773
# n_neighbors = 100:
#   Mean cross-validation score: 0.2767
# n_neighbors = 101:
#   Mean cross-validation score: 0.2768
# n_neighbors = 102:
#   Mean cross-validation score: 0.2761
# n_neighbors = 103:
#   Mean cross-validation score: 0.2757
# n_neighbors = 104:
#   Mean cross-validation score: 0.2760
# n_neighbors = 105:
#   Mean cross-validation score: 0.2751
# n_neighbors = 106:
#   Mean cross-validation score: 0.2757
# n_neighbors = 107:
#   Mean cross-validation score: 0.2758
# n_neighbors = 108:
#   Mean cross-validation score: 0.2750
# n_neighbors = 109:
#   Mean cross-validation score: 0.2749
# n_neighbors = 110:
#   Mean cross-validation score: 0.2743
# n_neighbors = 111:
#   Mean cross-validation score: 0.2753
# n_neighbors = 112:
#   Mean cross-validation score: 0.2753
# n_neighbors = 113:
#   Mean cross-validation score: 0.2750
# n_neighbors = 114:
#   Mean cross-validation score: 0.2747
# n_neighbors = 115:
#   Mean cross-validation score: 0.2739
# n_neighbors = 116:
#   Mean cross-validation score: 0.2737
# n_neighbors = 117:
#   Mean cross-validation score: 0.2737
# n_neighbors = 118:
#   Mean cross-validation score: 0.2734
# n_neighbors = 119:
#   Mean cross-validation score: 0.2741
# n_neighbors = 120:
#   Mean cross-validation score: 0.2735
# n_neighbors = 121:
#   Mean cross-validation score: 0.2742
# n_neighbors = 122:
#   Mean cross-validation score: 0.2747
# n_neighbors = 123:
#   Mean cross-validation score: 0.2734
# n_neighbors = 124:
#   Mean cross-validation score: 0.2733
# n_neighbors = 125:
#   Mean cross-validation score: 0.2738
# n_neighbors = 126:
#   Mean cross-validation score: 0.2747
# n_neighbors = 127:
#   Mean cross-validation score: 0.2731
# n_neighbors = 128:
#   Mean cross-validation score: 0.2727
# n_neighbors = 129:
#   Mean cross-validation score: 0.2730
# n_neighbors = 130:
#   Mean cross-validation score: 0.2726
# n_neighbors = 131:
#   Mean cross-validation score: 0.2717
# n_neighbors = 132:
#   Mean cross-validation score: 0.2721
# n_neighbors = 133:
#   Mean cross-validation score: 0.2724
# n_neighbors = 134:
#   Mean cross-validation score: 0.2722
# n_neighbors = 135:
#   Mean cross-validation score: 0.2717
# n_neighbors = 136:
#   Mean cross-validation score: 0.2717
# n_neighbors = 137:
#   Mean cross-validation score: 0.2710
# n_neighbors = 138:
#   Mean cross-validation score: 0.2703
# n_neighbors = 139:
#   Mean cross-validation score: 0.2701
# n_neighbors = 140:
#   Mean cross-validation score: 0.2700
# n_neighbors = 141:
#   Mean cross-validation score: 0.2702
# n_neighbors = 142:
#   Mean cross-validation score: 0.2695
# n_neighbors = 143:
#   Mean cross-validation score: 0.2693
# n_neighbors = 144:
#   Mean cross-validation score: 0.2692
# n_neighbors = 145:
#   Mean cross-validation score: 0.2690
# n_neighbors = 146:
#   Mean cross-validation score: 0.2687
# n_neighbors = 147:
#   Mean cross-validation score: 0.2687
# n_neighbors = 148:
#   Mean cross-validation score: 0.2687
# n_neighbors = 149:
#   Mean cross-validation score: 0.2690
# n_neighbors = 150:
#   Mean cross-validation score: 0.2685
# n_neighbors = 151:
#   Mean cross-validation score: 0.2683
# n_neighbors = 152:
#   Mean cross-validation score: 0.2675
# n_neighbors = 153:
#   Mean cross-validation score: 0.2671
# n_neighbors = 154:
#   Mean cross-validation score: 0.2671
# n_neighbors = 155:
#   Mean cross-validation score: 0.2680
# n_neighbors = 156:
#   Mean cross-validation score: 0.2676
# n_neighbors = 157:
#   Mean cross-validation score: 0.2670
# n_neighbors = 158:
#   Mean cross-validation score: 0.2674
# n_neighbors = 159:
#   Mean cross-validation score: 0.2673
# n_neighbors = 160:
#   Mean cross-validation score: 0.2671
# n_neighbors = 161:
#   Mean cross-validation score: 0.2667
# n_neighbors = 162:
#   Mean cross-validation score: 0.2666
# n_neighbors = 163:
#   Mean cross-validation score: 0.2666
# n_neighbors = 164:
#   Mean cross-validation score: 0.2665
# n_neighbors = 165:
#   Mean cross-validation score: 0.2661
# n_neighbors = 166:
#   Mean cross-validation score: 0.2658
# n_neighbors = 167:
#   Mean cross-validation score: 0.2658
# n_neighbors = 168:
#   Mean cross-validation score: 0.2662
# n_neighbors = 169:
#   Mean cross-validation score: 0.2660
# n_neighbors = 170:
#   Mean cross-validation score: 0.2657
# n_neighbors = 171:
#   Mean cross-validation score: 0.2653
# n_neighbors = 172:
#   Mean cross-validation score: 0.2663
# n_neighbors = 173:
#   Mean cross-validation score: 0.2657
# n_neighbors = 174:
#   Mean cross-validation score: 0.2658
# n_neighbors = 175:
#   Mean cross-validation score: 0.2661
# n_neighbors = 176:
#   Mean cross-validation score: 0.2666
# n_neighbors = 177:
#   Mean cross-validation score: 0.2661
# n_neighbors = 178:
#   Mean cross-validation score: 0.2660
# n_neighbors = 179:
#   Mean cross-validation score: 0.2660
# n_neighbors = 180:
#   Mean cross-validation score: 0.2663
# n_neighbors = 181:
#   Mean cross-validation score: 0.2659
# n_neighbors = 182:
#   Mean cross-validation score: 0.2659
# n_neighbors = 183:
#   Mean cross-validation score: 0.2655
# n_neighbors = 184:
#   Mean cross-validation score: 0.2662
# n_neighbors = 185:
#   Mean cross-validation score: 0.2649
# n_neighbors = 186:
#   Mean cross-validation score: 0.2657
# n_neighbors = 187:
#   Mean cross-validation score: 0.2662
# n_neighbors = 188:
#   Mean cross-validation score: 0.2655
# n_neighbors = 189:
#   Mean cross-validation score: 0.2659
# n_neighbors = 190:
#   Mean cross-validation score: 0.2654
# n_neighbors = 191:
#   Mean cross-validation score: 0.2657
# n_neighbors = 192:
#   Mean cross-validation score: 0.2645
# n_neighbors = 193:
#   Mean cross-validation score: 0.2645
# n_neighbors = 194:
#   Mean cross-validation score: 0.2647
# n_neighbors = 195:
#   Mean cross-validation score: 0.2650
# n_neighbors = 196:
#   Mean cross-validation score: 0.2643
# n_neighbors = 197:
#   Mean cross-validation score: 0.2641
# n_neighbors = 198:
#   Mean cross-validation score: 0.2639
# n_neighbors = 199:
#   Mean cross-validation score: 0.2640
# n_neighbors = 200:
#   Mean cross-validation score: 0.2642

# %%
# return the precision, recall and f1-score in each class

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=grid_search.best_params_['knn__n_neighbors']))
])

# Get predictions of the testing data
pipe.fit(train_images_project, train_Class)
pred = pipe.predict(test_images_project)

# print test accuracy
print(accuracy_score(test_Class, pred))
        
#
# print detailed classification report
print(classification_report(test_Class, pred))
# Out:
# 0.4020618556701031
#               precision    recall  f1-score   support
#
#        angry       0.37      0.31      0.34       958
#      disgust       0.36      0.57      0.44       111
#         fear       0.38      0.38      0.38      1024
#        happy       0.50      0.41      0.45      1774
#      neutral       0.30      0.45      0.36      1233
#          sad       0.35      0.30      0.32      1247
#     surprise       0.61      0.58      0.60       831
#
#     accuracy                           0.40      7178
#    macro avg       0.41      0.43      0.41      7178
# weighted avg       0.41      0.40      0.40      7178
